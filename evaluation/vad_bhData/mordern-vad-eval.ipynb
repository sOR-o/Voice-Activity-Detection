# %%
import os
import torch
import torchaudio
import pandas as pd
import numpy as np
from funasr import AutoModel
import soundfile as sf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score, classification_report
from speechbrain.inference.VAD import VAD
import seaborn as sns
from pyannote.core import Segment
from pyannote.audio import Pipeline
# Out:
# Notice: ffmpeg is not installed. torchaudio is used to load audio
# If you want to use ffmpeg backend to load audio, please install it by:
# 	sudo apt install ffmpeg # ubuntu
# 	# brew install ffmpeg # mac

# %%
# silero

SAMPLING_RATE = 16000
torch.set_num_threads(1)

torch.hub.set_dir('../models/.cache')
model_silero, utils_silero = torch.hub.load(repo_or_dir='snakers4/silero-vad',
                              model='silero_vad',
                              force_reload=True,
                              onnx=False)

(get_speech_timestamps,
 save_audio,
 read_audio,
 VADIterator,
 collect_chunks) = utils_silero

 # pyannote
pipeline = Pipeline.from_pretrained (
        "pyannote/voice-activity-detection",
         use_auth_token="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", # Once while downloading the model
        cache_dir="../models/.cache"
        )

# speechbrain
vad = VAD.from_hparams(
        source="speechbrain/vad-crdnn-libriparty",
        savedir="../models/.cache"  # Save the model in a cache folder
)

# funasr
model_funasr = AutoModel(model="fsmn-vad", model_revision="v2.0.4", device="cuda")
# Out:
# Downloading: "https://github.com/snakers4/silero-vad/zipball/master" to ../models/.cache/master.zip
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.1.3 to v2.3.0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../../../../../.cache/torch/pyannote/models--pyannote--segmentation/snapshots/059e96f964841d40f1a5e755bb7223f76666bba4/pytorch_model.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.3.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.7.1, yours is 2.3.1. Bad things might happen unless you revert torch to 1.x.
# 2024-10-16 18:51:02,905 - modelscope - INFO - PyTorch version 2.3.1 Found.
# 2024-10-16 18:51:02,907 - modelscope - INFO - Loading ast index from /Users/saurabh/.cache/modelscope/ast_indexer
# 2024-10-16 18:51:03,053 - modelscope - INFO - Loading done! Current index file version is 1.15.0, with md5 270895fc7d76b5c7655183a5b4e2f1dd and a total number of 980 components indexed
# 2024-10-16 18:51:04,453 - modelscope - INFO - Use user-specified model revision: v2.0.4

# %%
import sys
sys.path.append("/Users/saurabh/Documents/projects/Voice-Activity-Detection")

from helper import vad_inference_pyannote, print_timestamps_pyannote, run_vad_on_noisy_audio_pyannote, visualize_metrics_vs_SNR_pyannote
from helper import vad_inference_funasr, convert_to_timestamps_funasr, run_vad_on_noisy_audio_funasr, visualize_metrics_vs_SNR_funasr
from helper import vad_inference_silero, print_timestamps_silero, run_vad_on_noisy_audio_silero, visualize_metrics_vs_SNR_silero
from helper import vad_inference_speechbrain, print_timestamps_speechbrain, run_vad_on_noisy_audio_speechbrain, visualize_metrics_vs_SNR_speechbrain
from helper.vad import parse_annotations_file_bh, evaluate_vad, add_noise, save_audio, plot_SNR, extract_metrics, visualize_all_metrics, evaluate_vad_cmatrix, plot_confusion_matrices, get_file_paths, read_path, parse_annotations_file, average_metrics, show_vad_matrix_bh, save_results_to_csv, extract_speech_segments, count_continuous_zeros_after_start_segments, count_continuous_ones_after_end_segments, calculate_fec, calculate_msc, calculate_over, calculate_nds, save_results_to_csv1, show_vad_metrics_matrix1

# %%
wav_directory = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/data/bh_dataset/bh_audios"
label_directory = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/data/bh_dataset/labels"


audio_paths, label_paths = read_path(wav_directory, label_directory)
audio_paths.sort()
label_paths.sort()
annotated_segments = [parse_annotations_file_bh(label_path) for label_path in label_paths] 

# label_paths = label_paths[:20]
# audio_paths = audio_paths[:20]
# annotated_segments = annotated_segments[:20]

# %%
result_pyannote = []
result_silero = []
result_speechbrain = []
result_funasr = []
cmatrix_pyannote = []
cmatrix_silero = []
cmatrix_speechbrain = []
cmatrix_funasr = []

# %%
for i in range(len(audio_paths)):
    pyannote = vad_inference_pyannote(pipeline, audio_paths[i])
    funasr = vad_inference_funasr(audio_paths[i], model_funasr)
    silero = vad_inference_silero(audio_paths[i], model_silero, utils_silero, sampling_rate=SAMPLING_RATE)
    speechbrain = vad_inference_speechbrain(audio_paths[i], vad)

    pyannote = print_timestamps_pyannote(pyannote)
    funasr = convert_to_timestamps_funasr(funasr)
    silero = print_timestamps_silero(silero)
    speechbrain = print_timestamps_speechbrain(speechbrain)

    cmatrix_pyannote.append(evaluate_vad_cmatrix(pyannote, annotated_segments[i]))
    cmatrix_silero.append(evaluate_vad_cmatrix(silero, annotated_segments[i]))
    cmatrix_speechbrain.append(evaluate_vad_cmatrix(speechbrain, annotated_segments[i]))
    cmatrix_funasr.append(evaluate_vad_cmatrix(funasr, annotated_segments[i]))

    result_pyannote.append(pyannote)
    result_silero.append(silero)
    result_speechbrain.append(speechbrain)
    result_funasr.append(funasr)
# Out:
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.12it/s]
# {'load_data': '0.003', 'extract_feat': '0.017', 'forward': '0.110', 'batch_size': '1', 'rtf': '0.020'}, : 100%|█| 1
# rtf_avg: 0.020: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.44it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.48it/s]
# {'load_data': '0.003', 'extract_feat': '0.011', 'forward': '0.105', 'batch_size': '1', 'rtf': '0.015'}, : 100%|█| 1
# rtf_avg: 0.015: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.72it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.010', 'forward': '0.084', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.41it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.003', 'extract_feat': '0.012', 'forward': '0.096', 'batch_size': '1', 'rtf': '0.012'}, : 100%|█| 1
# rtf_avg: 0.012: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.05it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.015', 'forward': '0.096', 'batch_size': '1', 'rtf': '0.018'}, : 100%|█| 1
# rtf_avg: 0.018: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.86it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.011', 'forward': '0.091', 'batch_size': '1', 'rtf': '0.015'}, : 100%|█| 1
# rtf_avg: 0.015: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.30it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.77it/s]
# {'load_data': '0.005', 'extract_feat': '0.038', 'forward': '0.265', 'batch_size': '1', 'rtf': '0.016'}, : 100%|█| 1
# rtf_avg: 0.016: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.64it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.32it/s]
# {'load_data': '0.003', 'extract_feat': '0.020', 'forward': '0.188', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.12it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.65it/s]
# {'load_data': '0.005', 'extract_feat': '0.025', 'forward': '0.215', 'batch_size': '1', 'rtf': '0.019'}, : 100%|█| 1
# rtf_avg: 0.019: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.34it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.10it/s]
# {'load_data': '0.002', 'extract_feat': '0.018', 'forward': '0.141', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.83it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.58it/s]
# {'load_data': '0.002', 'extract_feat': '0.010', 'forward': '0.104', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# rtf_avg: 0.017: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.90it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.46it/s]
# {'load_data': '0.003', 'extract_feat': '0.020', 'forward': '0.155', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.20it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.54it/s]
# {'load_data': '0.004', 'extract_feat': '0.016', 'forward': '0.133', 'batch_size': '1', 'rtf': '0.015'}, : 100%|█| 1
# rtf_avg: 0.015: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.18it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.005', 'forward': '0.069', 'batch_size': '1', 'rtf': '0.021'}, : 100%|█| 1
# rtf_avg: 0.021: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.35it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.39it/s]
# {'load_data': '0.003', 'extract_feat': '0.013', 'forward': '0.135', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# rtf_avg: 0.017: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.93it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.07it/s]
# {'load_data': '0.002', 'extract_feat': '0.018', 'forward': '0.165', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.76it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.79it/s]
# {'load_data': '0.002', 'extract_feat': '0.017', 'forward': '0.209', 'batch_size': '1', 'rtf': '0.028'}, : 100%|█| 1
# rtf_avg: 0.028: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.56it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.37it/s]
# {'load_data': '0.004', 'extract_feat': '0.054', 'forward': '0.422', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.33it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.00it/s]
# {'load_data': '0.003', 'extract_feat': '0.018', 'forward': '0.167', 'batch_size': '1', 'rtf': '0.013'}, : 100%|█| 1
# rtf_avg: 0.013: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.76it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.07it/s]
# {'load_data': '0.002', 'extract_feat': '0.015', 'forward': '0.141', 'batch_size': '1', 'rtf': '0.018'}, : 100%|█| 1
# rtf_avg: 0.018: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.40it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.008', 'forward': '0.088', 'batch_size': '1', 'rtf': '0.023'}, : 100%|█| 1
# rtf_avg: 0.023: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.76it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.25it/s]
# {'load_data': '0.003', 'extract_feat': '0.022', 'forward': '0.121', 'batch_size': '1', 'rtf': '0.029'}, : 100%|█| 1
# rtf_avg: 0.029: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.82it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.23it/s]
# {'load_data': '0.004', 'extract_feat': '0.013', 'forward': '0.138', 'batch_size': '1', 'rtf': '0.019'}, : 100%|█| 1
# rtf_avg: 0.019: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.91it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.21it/s]
# {'load_data': '0.003', 'extract_feat': '0.020', 'forward': '0.139', 'batch_size': '1', 'rtf': '0.015'}, : 100%|█| 1
# rtf_avg: 0.015: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.82it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.13it/s]
# {'load_data': '0.002', 'extract_feat': '0.014', 'forward': '0.123', 'batch_size': '1', 'rtf': '0.019'}, : 100%|█| 1
# rtf_avg: 0.019: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.63it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.003', 'extract_feat': '0.014', 'forward': '0.098', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.65it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.52it/s]
# {'load_data': '0.002', 'extract_feat': '0.013', 'forward': '0.153', 'batch_size': '1', 'rtf': '0.020'}, : 100%|█| 1
# rtf_avg: 0.020: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.26it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.009', 'forward': '0.085', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.21it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.03it/s]
# {'load_data': '0.002', 'extract_feat': '0.012', 'forward': '0.142', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# rtf_avg: 0.017: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.75it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.58it/s]
# {'load_data': '0.002', 'extract_feat': '0.042', 'forward': '0.117', 'batch_size': '1', 'rtf': '0.036'}, : 100%|█| 1
# rtf_avg: 0.036: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.96it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.91it/s]
# {'load_data': '0.002', 'extract_feat': '0.011', 'forward': '0.101', 'batch_size': '1', 'rtf': '0.012'}, : 100%|█| 1
# rtf_avg: 0.012: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.11it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.05it/s]
# {'load_data': '0.002', 'extract_feat': '0.010', 'forward': '0.124', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# rtf_avg: 0.017: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.64it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.005', 'forward': '0.050', 'batch_size': '1', 'rtf': '0.020'}, : 100%|█| 1
# rtf_avg: 0.020: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 17.43it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.43it/s]
# {'load_data': '0.002', 'extract_feat': '0.027', 'forward': '0.106', 'batch_size': '1', 'rtf': '0.043'}, : 100%|█| 1
# rtf_avg: 0.043: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.74it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.27it/s]
# {'load_data': '0.003', 'extract_feat': '0.008', 'forward': '0.108', 'batch_size': '1', 'rtf': '0.030'}, : 100%|█| 1
# rtf_avg: 0.030: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.84it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.004', 'extract_feat': '0.007', 'forward': '0.085', 'batch_size': '1', 'rtf': '0.024'}, : 100%|█| 1
# rtf_avg: 0.024: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.04it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.20it/s]
# {'load_data': '0.002', 'extract_feat': '0.009', 'forward': '0.122', 'batch_size': '1', 'rtf': '0.023'}, : 100%|█| 1
# rtf_avg: 0.023: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.75it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.67it/s]
# {'load_data': '0.005', 'extract_feat': '0.021', 'forward': '0.130', 'batch_size': '1', 'rtf': '0.038'}, : 100%|█| 1
# rtf_avg: 0.038: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.28it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.67it/s]
# {'load_data': '0.002', 'extract_feat': '0.008', 'forward': '0.176', 'batch_size': '1', 'rtf': '0.033'}, : 100%|█| 1
# rtf_avg: 0.033: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.50it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.011', 'forward': '0.097', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# rtf_avg: 0.017: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.87it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.006', 'extract_feat': '0.012', 'forward': '0.072', 'batch_size': '1', 'rtf': '0.021'}, : 100%|█| 1
# rtf_avg: 0.021: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.87it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.004', 'extract_feat': '0.009', 'forward': '0.085', 'batch_size': '1', 'rtf': '0.024'}, : 100%|█| 1
# rtf_avg: 0.024: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.94it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.001', 'extract_feat': '0.006', 'forward': '0.055', 'batch_size': '1', 'rtf': '0.020'}, : 100%|█| 1
# rtf_avg: 0.020: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.23it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.74it/s]
# {'load_data': '0.002', 'extract_feat': '0.012', 'forward': '0.129', 'batch_size': '1', 'rtf': '0.019'}, : 100%|█| 1
# rtf_avg: 0.019: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.28it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.92it/s]
# {'load_data': '0.003', 'extract_feat': '0.026', 'forward': '0.342', 'batch_size': '1', 'rtf': '0.041'}, : 100%|█| 1
# rtf_avg: 0.041: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.85it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.008', 'forward': '0.057', 'batch_size': '1', 'rtf': '0.015'}, : 100%|█| 1
# rtf_avg: 0.015: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.98it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.08it/s]
# {'load_data': '0.002', 'extract_feat': '0.012', 'forward': '0.141', 'batch_size': '1', 'rtf': '0.018'}, : 100%|█| 1
# rtf_avg: 0.018: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.79it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.41it/s]
# {'load_data': '0.002', 'extract_feat': '0.010', 'forward': '0.156', 'batch_size': '1', 'rtf': '0.021'}, : 100%|█| 1
# rtf_avg: 0.021: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.19it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.90it/s]
# {'load_data': '0.002', 'extract_feat': '0.011', 'forward': '0.169', 'batch_size': '1', 'rtf': '0.026'}, : 100%|█| 1
# rtf_avg: 0.026: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.58it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.96it/s]
# {'load_data': '0.002', 'extract_feat': '0.015', 'forward': '0.144', 'batch_size': '1', 'rtf': '0.026'}, : 100%|█| 1
# rtf_avg: 0.026: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.70it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.59it/s]
# {'load_data': '0.002', 'extract_feat': '0.014', 'forward': '0.132', 'batch_size': '1', 'rtf': '0.016'}, : 100%|█| 1
# rtf_avg: 0.016: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.18it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.56it/s]
# {'load_data': '0.002', 'extract_feat': '0.012', 'forward': '0.105', 'batch_size': '1', 'rtf': '0.013'}, : 100%|█| 1
# rtf_avg: 0.013: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.94it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.91it/s]
# {'load_data': '0.004', 'extract_feat': '0.041', 'forward': '0.343', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.86it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.44it/s]
# {'load_data': '0.002', 'extract_feat': '0.015', 'forward': '0.155', 'batch_size': '1', 'rtf': '0.018'}, : 100%|█| 1
# rtf_avg: 0.018: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.20it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.004', 'extract_feat': '0.009', 'forward': '0.085', 'batch_size': '1', 'rtf': '0.028'}, : 100%|█| 1
# rtf_avg: 0.028: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.01it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.009', 'forward': '0.079', 'batch_size': '1', 'rtf': '0.020'}, : 100%|█| 1
# rtf_avg: 0.020: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.96it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.007', 'forward': '0.065', 'batch_size': '1', 'rtf': '0.016'}, : 100%|█| 1
# rtf_avg: 0.016: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.23it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.008', 'forward': '0.093', 'batch_size': '1', 'rtf': '0.021'}, : 100%|█| 1
# rtf_avg: 0.021: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.28it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.08it/s]
# {'load_data': '0.003', 'extract_feat': '0.013', 'forward': '0.124', 'batch_size': '1', 'rtf': '0.016'}, : 100%|█| 1
# rtf_avg: 0.016: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.68it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.009', 'forward': '0.066', 'batch_size': '1', 'rtf': '0.015'}, : 100%|█| 1
# rtf_avg: 0.015: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.35it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.46it/s]
# {'load_data': '0.002', 'extract_feat': '0.010', 'forward': '0.106', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# rtf_avg: 0.017: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.96it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.09it/s]
# {'load_data': '0.003', 'extract_feat': '0.016', 'forward': '0.141', 'batch_size': '1', 'rtf': '0.020'}, : 100%|█| 1
# rtf_avg: 0.020: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.71it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.003', 'extract_feat': '0.010', 'forward': '0.083', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.37it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.97it/s]
# {'load_data': '0.003', 'extract_feat': '0.009', 'forward': '0.100', 'batch_size': '1', 'rtf': '0.018'}, : 100%|█| 1
# rtf_avg: 0.018: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.45it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.003', 'extract_feat': '0.011', 'forward': '0.080', 'batch_size': '1', 'rtf': '0.013'}, : 100%|█| 1
# rtf_avg: 0.013: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.95it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.66it/s]
# {'load_data': '0.002', 'extract_feat': '0.008', 'forward': '0.103', 'batch_size': '1', 'rtf': '0.016'}, : 100%|█| 1
# rtf_avg: 0.016: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.24it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.001', 'extract_feat': '0.008', 'forward': '0.066', 'batch_size': '1', 'rtf': '0.016'}, : 100%|█| 1
# rtf_avg: 0.016: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.44it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.009', 'forward': '0.082', 'batch_size': '1', 'rtf': '0.013'}, : 100%|█| 1
# rtf_avg: 0.013: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.41it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.95it/s]
# {'load_data': '0.002', 'extract_feat': '0.013', 'forward': '0.100', 'batch_size': '1', 'rtf': '0.015'}, : 100%|█| 1
# rtf_avg: 0.015: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.44it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.001', 'extract_feat': '0.007', 'forward': '0.070', 'batch_size': '1', 'rtf': '0.013'}, : 100%|█| 1
# rtf_avg: 0.013: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.09it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.74it/s]
# {'load_data': '0.003', 'extract_feat': '0.010', 'forward': '0.114', 'batch_size': '1', 'rtf': '0.028'}, : 100%|█| 1
# rtf_avg: 0.028: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.17it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.009', 'forward': '0.077', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.15it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.79it/s]
# {'load_data': '0.003', 'extract_feat': '0.020', 'forward': '0.209', 'batch_size': '1', 'rtf': '0.023'}, : 100%|█| 1
# rtf_avg: 0.023: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.61it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.012', 'forward': '0.080', 'batch_size': '1', 'rtf': '0.016'}, : 100%|█| 1
# rtf_avg: 0.016: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.88it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.67it/s]
# {'load_data': '0.004', 'extract_feat': '0.030', 'forward': '0.272', 'batch_size': '1', 'rtf': '0.013'}, : 100%|█| 1
# rtf_avg: 0.013: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.58it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.45it/s]
# {'load_data': '0.002', 'extract_feat': '0.011', 'forward': '0.106', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.00it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.16it/s]
# {'load_data': '0.002', 'extract_feat': '0.010', 'forward': '0.109', 'batch_size': '1', 'rtf': '0.013'}, : 100%|█| 1
# rtf_avg: 0.013: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.77it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.006', 'forward': '0.064', 'batch_size': '1', 'rtf': '0.020'}, : 100%|█| 1
# rtf_avg: 0.020: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.36it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.56it/s]
# {'load_data': '0.004', 'extract_feat': '0.011', 'forward': '0.281', 'batch_size': '1', 'rtf': '0.094'}, : 100%|█| 1
# rtf_avg: 0.094: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.48it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.43it/s]
# {'load_data': '0.002', 'extract_feat': '0.028', 'forward': '0.184', 'batch_size': '1', 'rtf': '0.025'}, : 100%|█| 1
# rtf_avg: 0.025: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.19it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.66it/s]
# {'load_data': '0.002', 'extract_feat': '0.015', 'forward': '0.177', 'batch_size': '1', 'rtf': '0.021'}, : 100%|█| 1
# rtf_avg: 0.021: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.45it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.58it/s]
# {'load_data': '0.014', 'extract_feat': '0.017', 'forward': '0.179', 'batch_size': '1', 'rtf': '0.023'}, : 100%|█| 1
# rtf_avg: 0.023: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.35it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.007', 'forward': '0.073', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.70it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.66it/s]
# {'load_data': '0.002', 'extract_feat': '0.011', 'forward': '0.115', 'batch_size': '1', 'rtf': '0.019'}, : 100%|█| 1
# rtf_avg: 0.019: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.35it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.04it/s]
# {'load_data': '0.002', 'extract_feat': '0.015', 'forward': '0.248', 'batch_size': '1', 'rtf': '0.027'}, : 100%|█| 1
# rtf_avg: 0.027: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.95it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.007', 'forward': '0.070', 'batch_size': '1', 'rtf': '0.018'}, : 100%|█| 1
# rtf_avg: 0.018: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.47it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.16it/s]
# {'load_data': '0.003', 'extract_feat': '0.014', 'forward': '0.140', 'batch_size': '1', 'rtf': '0.013'}, : 100%|█| 1
# rtf_avg: 0.013: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.83it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.22it/s]
# {'load_data': '0.002', 'extract_feat': '0.013', 'forward': '0.161', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# rtf_avg: 0.017: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.99it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.009', 'forward': '0.075', 'batch_size': '1', 'rtf': '0.015'}, : 100%|█| 1
# rtf_avg: 0.015: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.03it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.009', 'forward': '0.086', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# rtf_avg: 0.017: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.97it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.57it/s]
# {'load_data': '0.002', 'extract_feat': '0.011', 'forward': '0.104', 'batch_size': '1', 'rtf': '0.013'}, : 100%|█| 1
# rtf_avg: 0.013: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.06it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.011', 'forward': '0.096', 'batch_size': '1', 'rtf': '0.015'}, : 100%|█| 1
# rtf_avg: 0.015: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.99it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.008', 'forward': '0.093', 'batch_size': '1', 'rtf': '0.019'}, : 100%|█| 1
# rtf_avg: 0.019: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.99it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.68it/s]
# {'load_data': '0.002', 'extract_feat': '0.011', 'forward': '0.130', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.39it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.14it/s]
# {'load_data': '0.002', 'extract_feat': '0.011', 'forward': '0.140', 'batch_size': '1', 'rtf': '0.019'}, : 100%|█| 1
# rtf_avg: 0.019: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.85it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.97it/s]
# {'load_data': '0.001', 'extract_feat': '0.009', 'forward': '0.144', 'batch_size': '1', 'rtf': '0.027'}, : 100%|█| 1
# rtf_avg: 0.027: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.69it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.51it/s]
# {'load_data': '0.002', 'extract_feat': '0.013', 'forward': '0.154', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.24it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.70it/s]
# {'load_data': '0.003', 'extract_feat': '0.022', 'forward': '0.213', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# rtf_avg: 0.017: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.58it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.08it/s]
# {'load_data': '0.002', 'extract_feat': '0.016', 'forward': '0.141', 'batch_size': '1', 'rtf': '0.018'}, : 100%|█| 1
# rtf_avg: 0.018: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.80it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.99it/s]
# {'load_data': '0.003', 'extract_feat': '0.018', 'forward': '0.143', 'batch_size': '1', 'rtf': '0.016'}, : 100%|█| 1
# rtf_avg: 0.016: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.64it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.001', 'extract_feat': '0.008', 'forward': '0.050', 'batch_size': '1', 'rtf': '0.016'}, : 100%|█| 1
# rtf_avg: 0.016: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 17.82it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.85it/s]
# {'load_data': '0.002', 'extract_feat': '0.015', 'forward': '0.127', 'batch_size': '1', 'rtf': '0.016'}, : 100%|█| 1
# rtf_avg: 0.016: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.51it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.29it/s]
# {'load_data': '0.002', 'extract_feat': '0.012', 'forward': '0.137', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# rtf_avg: 0.017: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.01it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.57it/s]
# {'load_data': '0.003', 'extract_feat': '0.021', 'forward': '0.219', 'batch_size': '1', 'rtf': '0.016'}, : 100%|█| 1
# rtf_avg: 0.016: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.44it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.001', 'extract_feat': '0.006', 'forward': '0.073', 'batch_size': '1', 'rtf': '0.020'}, : 100%|█| 1
# rtf_avg: 0.020: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.71it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.29it/s]
# {'load_data': '0.003', 'extract_feat': '0.022', 'forward': '0.108', 'batch_size': '1', 'rtf': '0.034'}, : 100%|█| 1
# rtf_avg: 0.034: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.82it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.54it/s]
# {'load_data': '0.002', 'extract_feat': '0.015', 'forward': '0.117', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# rtf_avg: 0.017: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.94it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.016', 'forward': '0.087', 'batch_size': '1', 'rtf': '0.020'}, : 100%|█| 1
# rtf_avg: 0.020: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.94it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.38it/s]
# {'load_data': '0.002', 'extract_feat': '0.012', 'forward': '0.135', 'batch_size': '1', 'rtf': '0.016'}, : 100%|█| 1
# rtf_avg: 0.016: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.06it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.72it/s]
# {'load_data': '0.010', 'extract_feat': '0.037', 'forward': '0.583', 'batch_size': '1', 'rtf': '0.019'}, : 100%|█| 1
# rtf_avg: 0.019: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.69it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.63it/s]
# {'load_data': '0.002', 'extract_feat': '0.014', 'forward': '0.104', 'batch_size': '1', 'rtf': '0.019'}, : 100%|█| 1
# rtf_avg: 0.019: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.92it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.001', 'extract_feat': '0.009', 'forward': '0.081', 'batch_size': '1', 'rtf': '0.016'}, : 100%|█| 1
# rtf_avg: 0.016: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.72it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.008', 'forward': '0.089', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# ...
# {'load_data': '0.002', 'extract_feat': '0.009', 'forward': '0.099', 'batch_size': '1', 'rtf': '0.034'}, : 100%|█| 1
# rtf_avg: 0.034: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.47it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.003', 'extract_feat': '0.006', 'forward': '0.073', 'batch_size': '1', 'rtf': '0.023'}, : 100%|█| 1
# rtf_avg: 0.023: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.17it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.003', 'extract_feat': '0.033', 'forward': '0.091', 'batch_size': '1', 'rtf': '0.028'}, : 100%|█| 1
# rtf_avg: 0.028: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.52it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.003', 'extract_feat': '0.007', 'forward': '0.058', 'batch_size': '1', 'rtf': '0.019'}, : 100%|█| 1
# rtf_avg: 0.019: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.08it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.010', 'forward': '0.069', 'batch_size': '1', 'rtf': '0.022'}, : 100%|█| 1
# rtf_avg: 0.022: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.64it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.41it/s]
# {'load_data': '0.007', 'extract_feat': '0.067', 'forward': '0.708', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.40it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.53it/s]
# {'load_data': '0.003', 'extract_feat': '0.014', 'forward': '0.153', 'batch_size': '1', 'rtf': '0.030'}, : 100%|█| 1
# rtf_avg: 0.030: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.07it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.009', 'forward': '0.083', 'batch_size': '1', 'rtf': '0.027'}, : 100%|█| 1
# rtf_avg: 0.027: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.24it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.68it/s]
# {'load_data': '0.007', 'extract_feat': '0.015', 'forward': '0.130', 'batch_size': '1', 'rtf': '0.040'}, : 100%|█| 1
# rtf_avg: 0.040: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.31it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.19it/s]
# {'load_data': '0.003', 'extract_feat': '0.013', 'forward': '0.122', 'batch_size': '1', 'rtf': '0.028'}, : 100%|█| 1
# rtf_avg: 0.028: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.79it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.005', 'forward': '0.065', 'batch_size': '1', 'rtf': '0.013'}, : 100%|█| 1
# rtf_avg: 0.013: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.44it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.001', 'extract_feat': '0.007', 'forward': '0.059', 'batch_size': '1', 'rtf': '0.015'}, : 100%|█| 1
# rtf_avg: 0.015: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.73it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.009', 'forward': '0.071', 'batch_size': '1', 'rtf': '0.013'}, : 100%|█| 1
# rtf_avg: 0.013: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.44it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.001', 'extract_feat': '0.005', 'forward': '0.048', 'batch_size': '1', 'rtf': '0.012'}, : 100%|█| 1
# rtf_avg: 0.012: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 19.27it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.007', 'forward': '0.064', 'batch_size': '1', 'rtf': '0.013'}, : 100%|█| 1
# rtf_avg: 0.013: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.34it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.006', 'forward': '0.044', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 21.03it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.008', 'forward': '0.078', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.11it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.006', 'forward': '0.061', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.27it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.001', 'extract_feat': '0.005', 'forward': '0.057', 'batch_size': '1', 'rtf': '0.011'}, : 100%|█| 1
# rtf_avg: 0.011: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.51it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.006', 'forward': '0.049', 'batch_size': '1', 'rtf': '0.011'}, : 100%|█| 1
# rtf_avg: 0.011: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 18.97it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.005', 'forward': '0.050', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 18.63it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.010', 'forward': '0.080', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.67it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.006', 'forward': '0.044', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# rtf_avg: 0.017: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 19.98it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.49it/s]
# {'load_data': '0.002', 'extract_feat': '0.010', 'forward': '0.118', 'batch_size': '1', 'rtf': '0.020'}, : 100%|█| 1
# rtf_avg: 0.020: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.08it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.005', 'forward': '0.031', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# rtf_avg: 0.017: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 28.23it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.92it/s]
# {'load_data': '0.005', 'extract_feat': '0.012', 'forward': '0.144', 'batch_size': '1', 'rtf': '0.023'}, : 100%|█| 1
# rtf_avg: 0.023: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.14it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.004', 'forward': '0.035', 'batch_size': '1', 'rtf': '0.018'}, : 100%|█| 1
# rtf_avg: 0.018: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 25.32it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.001', 'extract_feat': '0.011', 'forward': '0.079', 'batch_size': '1', 'rtf': '0.012'}, : 100%|█| 1
# rtf_avg: 0.012: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.12it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.40it/s]
# {'load_data': '0.005', 'extract_feat': '0.039', 'forward': '0.294', 'batch_size': '1', 'rtf': '0.049'}, : 100%|█| 1
# rtf_avg: 0.049: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.31it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.006', 'extract_feat': '0.008', 'forward': '0.089', 'batch_size': '1', 'rtf': '0.018'}, : 100%|█| 1
# rtf_avg: 0.018: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.21it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.34it/s]
# {'load_data': '0.002', 'extract_feat': '0.009', 'forward': '0.120', 'batch_size': '1', 'rtf': '0.017'}, : 100%|█| 1
# rtf_avg: 0.017: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.11it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.007', 'forward': '0.066', 'batch_size': '1', 'rtf': '0.011'}, : 100%|█| 1
# rtf_avg: 0.011: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.97it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.008', 'forward': '0.067', 'batch_size': '1', 'rtf': '0.012'}, : 100%|█| 1
# rtf_avg: 0.012: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.26it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.10it/s]
# {'load_data': '0.002', 'extract_feat': '0.011', 'forward': '0.110', 'batch_size': '1', 'rtf': '0.011'}, : 100%|█| 1
# rtf_avg: 0.011: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.77it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.001', 'extract_feat': '0.005', 'forward': '0.045', 'batch_size': '1', 'rtf': '0.009'}, : 100%|█| 1
# rtf_avg: 0.009: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 21.11it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.26it/s]
# {'load_data': '0.002', 'extract_feat': '0.010', 'forward': '0.138', 'batch_size': '1', 'rtf': '0.016'}, : 100%|█| 1
# rtf_avg: 0.016: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.63it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.002', 'extract_feat': '0.008', 'forward': '0.079', 'batch_size': '1', 'rtf': '0.011'}, : 100%|█| 1
# rtf_avg: 0.011: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.01it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.01it/s]
# {'load_data': '0.002', 'extract_feat': '0.015', 'forward': '0.143', 'batch_size': '1', 'rtf': '0.010'}, : 100%|█| 1
# rtf_avg: 0.010: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.76it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.001', 'extract_feat': '0.003', 'forward': '0.032', 'batch_size': '1', 'rtf': '0.010'}, : 100%|█| 1
# rtf_avg: 0.010: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 28.55it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.89it/s]
# {'load_data': '0.002', 'extract_feat': '0.010', 'forward': '0.101', 'batch_size': '1', 'rtf': '0.009'}, : 100%|█| 1
# rtf_avg: 0.009: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.53it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.001', 'extract_feat': '0.007', 'forward': '0.077', 'batch_size': '1', 'rtf': '0.012'}, : 100%|█| 1
# rtf_avg: 0.012: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.36it/s]
#
#   0%|                                                                                        | 0/1 [00:00<?, ?it/s]
# {'load_data': '0.001', 'extract_feat': '0.007', 'forward': '0.047', 'batch_size': '1', 'rtf': '0.014'}, : 100%|█| 1
# rtf_avg: 0.014: 100%|████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 19.67it/s]

# %%
# Initialize additional metrics containers
metrics_fec = {"Pyannote": [], "FunASR": [], "Silero": [], "SpeechBrain": []}
metrics_msc = {"Pyannote": [], "FunASR": [], "Silero": [], "SpeechBrain": []}
metrics_over = {"Pyannote": [], "FunASR": [], "Silero": [], "SpeechBrain": []}
metrics_nds = {"Pyannote": [], "FunASR": [], "Silero": [], "SpeechBrain": []}

# Evaluate each model on each audio file
for i in range(len(audio_paths)):
    # Compute additional metrics
    metrics_fec["Pyannote"].append(calculate_fec(cmatrix_pyannote[i][1], cmatrix_pyannote[i][0]))
    metrics_msc["Pyannote"].append(calculate_msc(cmatrix_pyannote[i][1], cmatrix_pyannote[i][0]))
    metrics_over["Pyannote"].append(calculate_over(cmatrix_pyannote[i][1], cmatrix_pyannote[i][0]))
    metrics_nds["Pyannote"].append(calculate_nds(cmatrix_pyannote[i][1], cmatrix_pyannote[i][0]))

    metrics_fec["FunASR"].append(calculate_fec(cmatrix_funasr[i][1], cmatrix_funasr[i][0]))
    metrics_msc["FunASR"].append(calculate_msc(cmatrix_funasr[i][1], cmatrix_funasr[i][0]))
    metrics_over["FunASR"].append(calculate_over(cmatrix_funasr[i][1], cmatrix_funasr[i][0]))
    metrics_nds["FunASR"].append(calculate_nds(cmatrix_funasr[i][1], cmatrix_funasr[i][0]))

    metrics_fec["Silero"].append(calculate_fec(cmatrix_silero[i][1], cmatrix_silero[i][0]))
    metrics_msc["Silero"].append(calculate_msc(cmatrix_silero[i][1], cmatrix_silero[i][0]))
    metrics_over["Silero"].append(calculate_over(cmatrix_silero[i][1], cmatrix_silero[i][0]))
    metrics_nds["Silero"].append(calculate_nds(cmatrix_silero[i][1], cmatrix_silero[i][0]))

    metrics_fec["SpeechBrain"].append(calculate_fec(cmatrix_speechbrain[i][1], cmatrix_speechbrain[i][0]))
    metrics_msc["SpeechBrain"].append(calculate_msc(cmatrix_speechbrain[i][1], cmatrix_speechbrain[i][0]))
    metrics_over["SpeechBrain"].append(calculate_over(cmatrix_speechbrain[i][1], cmatrix_speechbrain[i][0]))
    metrics_nds["SpeechBrain"].append(calculate_nds(cmatrix_speechbrain[i][1], cmatrix_speechbrain[i][0]))

# %%
show_vad_metrics_matrix1(metrics_fec, metrics_msc, metrics_over, metrics_nds, True)
# Out:
#        Pyannote     FunASR     Silero  SpeechBrain
# FEC    1.610035   0.153028   1.549347     0.791761
# MSC    2.595206   0.946955   2.747600     3.146990
# OVER  26.087973  35.521336  24.604093    15.878104
# NDS   14.403176  30.784292   8.226451    25.364403

# %%
model_names = ['Pyannote', 'FunASR', 'Silero', 'SpeechBrain']
save_results_to_csv1(metrics_fec, metrics_msc, metrics_over, metrics_nds, model_names, 'vad-new-bh.csv', label_paths)
