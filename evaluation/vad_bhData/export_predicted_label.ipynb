# %%
import os
import torch
import torchaudio
import pandas as pd
import numpy as np
from funasr import AutoModel
import soundfile as sf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score, classification_report
from speechbrain.inference.VAD import VAD
import seaborn as sns
from pyannote.core import Segment
from pyannote.audio import Pipeline
# Out:
# Notice: ffmpeg is not installed. torchaudio is used to load audio
# If you want to use ffmpeg backend to load audio, please install it by:
# 	sudo apt install ffmpeg # ubuntu
# 	# brew install ffmpeg # mac

# %%
# silero

SAMPLING_RATE = 16000
torch.set_num_threads(1)

torch.hub.set_dir('../models/.cache')
model_silero, utils_silero = torch.hub.load(repo_or_dir='snakers4/silero-vad',
                              model='silero_vad',
                              force_reload=True,
                              onnx=False)

(get_speech_timestamps,
 save_audio,
 read_audio,
 VADIterator,
 collect_chunks) = utils_silero

 # pyannote
pipeline = Pipeline.from_pretrained (
        "pyannote/voice-activity-detection",
         use_auth_token="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", # Once while downloading the model
        cache_dir="../models/.cache"
        )

# speechbrain
vad = VAD.from_hparams(
        source="speechbrain/vad-crdnn-libriparty",
        savedir="../models/.cache"  # Save the model in a cache folder
)

# funasr
model_funasr = AutoModel(model="fsmn-vad", model_revision="v2.0.4", device="cuda")
# Out:
# Downloading: "https://github.com/snakers4/silero-vad/zipball/master" to ../models/.cache/master.zip
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.1.3 to v2.3.0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../../../../../.cache/torch/pyannote/models--pyannote--segmentation/snapshots/059e96f964841d40f1a5e755bb7223f76666bba4/pytorch_model.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.3.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.7.1, yours is 2.3.1. Bad things might happen unless you revert torch to 1.x.
# 2024-10-21 15:47:25,205 - modelscope - INFO - PyTorch version 2.3.1 Found.
# 2024-10-21 15:47:25,207 - modelscope - INFO - Loading ast index from /Users/saurabh/.cache/modelscope/ast_indexer
# 2024-10-21 15:47:25,326 - modelscope - INFO - Loading done! Current index file version is 1.15.0, with md5 270895fc7d76b5c7655183a5b4e2f1dd and a total number of 980 components indexed
# 2024-10-21 15:47:27,375 - modelscope - INFO - Use user-specified model revision: v2.0.4

# %%
import sys
sys.path.append("/Users/saurabh/Documents/projects/Voice-Activity-Detection")

from helper import vad_inference_pyannote, print_timestamps_pyannote, run_vad_on_noisy_audio_pyannote, visualize_metrics_vs_SNR_pyannote
from helper import vad_inference_funasr, convert_to_timestamps_funasr, run_vad_on_noisy_audio_funasr, visualize_metrics_vs_SNR_funasr
from helper import vad_inference_silero, print_timestamps_silero, run_vad_on_noisy_audio_silero, visualize_metrics_vs_SNR_silero
from helper import vad_inference_speechbrain, print_timestamps_speechbrain, run_vad_on_noisy_audio_speechbrain, visualize_metrics_vs_SNR_speechbrain
from helper.vad import parse_annotations_file_bh, evaluate_vad, add_noise, save_audio, plot_SNR, extract_metrics, visualize_all_metrics, evaluate_vad_cmatrix, plot_confusion_matrices, get_file_paths, read_path, parse_annotations_file, average_metrics, show_vad_matrix_bh, save_results_to_csv, extract_speech_segments, count_continuous_zeros_after_start_segments, count_continuous_ones_after_end_segments, calculate_fec, calculate_msc, calculate_over, calculate_nds, save_results_to_csv1, show_vad_metrics_matrix1, save_multiple_speech_segments_as_text, extract_filenames_as_string

# %%
def get_filename(file_path):
    file_name = file_path.split('/')[-1]
    file_id = file_name.split('.')[0]
    return file_id

def parse_speech_segments(file_path):
    speech_segments = []
    with open(file_path, 'r') as file:
        for line in file:
            label, start_time, end_time = line.strip().split()
            if not label in ["!SIL"]:  # Only process lines where the label is 'S'

                
                speech_segments.append({
                    'speech': [round(float(start_time), 6), round(float(end_time), 6)]
                })
    return speech_segments

def generate_speech_segments_from_nonspeech_segments(nonspeech_segments, total_duration, margin=0.001):
    speech_segments = []
    current_time = 0.0

    for nonspeech in nonspeech_segments:
        nonspeech_start, nonspeech_end = nonspeech['nonspeech']

        if nonspeech_start > current_time:
            speech_segments.append({'speech': [round(current_time, 6), round(nonspeech_start - margin, 6)]})

        current_time = nonspeech_end + margin

    if current_time < total_duration:
        speech_segments.append({'speech': [round(current_time, 6), round(total_duration, 6)]})

    return speech_segments

def get_wav_duration(file_path):
    with wave.open(file_path, 'rb') as wav_file:
        n_frames = wav_file.getnframes()
        frame_rate = wav_file.getframerate()
        duration = n_frames / float(frame_rate)
        
        return duration

def extract_speech_segments_from_json(file_path, key):
    with open(file_path, 'r') as file:
        data = json.load(file)

    if key not in data:
        return []
        
    sil_value = data[key]["sil"]
    parsed_sil = eval(sil_value)
    output = [{'nonspeech': [float(num) for num in sublist]} for sublist in parsed_sil]

    wav_file = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/data/bh_dataset/bh_audios/" + key + ".wav"
    total_duraction = get_wav_duration(wav_file)
    
    output = generate_speech_segments_from_nonspeech_segments(output, total_duraction)
    
    return output

def show_vad_metrics_matrix1(metrics_fec, metrics_msc, metrics_over, metrics_nds, flag):
    models = ['Pyannote', 'FunASR', 'Silero', 'SpeechBrain', 'ASRmodel', 'newmodel']
    metrics = ['FEC', 'MSC', 'OVER', 'NDS']
    
    combined_data = {metric: {model: [] for model in models} for metric in metrics}
    
    for model_name in models:
        combined_data['FEC'][model_name] = metrics_fec[model_name]
        combined_data['MSC'][model_name] = metrics_msc[model_name]
        combined_data['OVER'][model_name] = metrics_over[model_name]
        combined_data['NDS'][model_name] = metrics_nds[model_name]
    
    average_data = {metric: {model: np.mean(combined_data[metric][model]) for model in models} for metric in metrics}
    
    df_combined = pd.DataFrame(average_data).T
    
    if flag:
        print(df_combined)

    plt.figure(figsize=(12, 8))
    plt.title("VAD Metrics Comparison")
    sns.heatmap(df_combined, annot=True, cmap="YlGnBu", fmt=".3f")
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.show()
    
def save_results_to_csv1(metrics_fec, metrics_msc, metrics_over, metrics_nds, model_names, output_file, label_paths):
    all_results = []
    num_files = len(metrics_fec[model_names[0]])  # Assumes all metrics have the same number of files

    for file_idx in range(num_files):
        file = label_paths[file_idx].split('.')[0].split('/')[-1]
        
        for model_name in model_names:
            fec_value = metrics_fec[model_name][file_idx]
            msc_value = metrics_msc[model_name][file_idx]
            over_value = metrics_over[model_name][file_idx]
            nds_value = metrics_nds[model_name][file_idx]

            result = {
                'model': model_name,
                'file index': file_idx,
                'audio file': file,
                'FEC': fec_value,
                'MSC': msc_value,
                'OVER': over_value,
                'NDS': nds_value
            }
            all_results.append(result)
    
    df = pd.DataFrame(all_results)
    df.to_csv(output_file, index=False)

# %%
wav_directory = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/data/bh_dataset/188_samples/188_audio"
label_directory = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/data/bh_dataset/188_samples/188_label_for_FE"
transcript_directory = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans"

_, label_paths = read_path(wav_directory, label_directory)
audio_paths, forced_paths = read_path(wav_directory, transcript_directory)

audio_paths.sort()
label_paths.sort()
forced_paths.sort()

annotated_segments = [parse_annotations_file_bh(label_path) for label_path in label_paths]

# %%
def filter_speech_segments(segments):
    # Keep only the dictionaries where the key is 'speech'
    speech_segments = [segment for segment in segments if 'speech' in segment]
    return speech_segments

def merge_speech_segments(speech_segments):
    if not speech_segments:
        return []

    start_time = speech_segments[0]['speech'][0]
    end_time = speech_segments[-1]['speech'][1]

    return [{'speech': [start_time, end_time]}]

# %%
res_silero = []
res_speechbrain = []

rr = []

# %%
for i in range(len(audio_paths)):
    silero = vad_inference_silero(audio_paths[i], model_silero, utils_silero, sampling_rate=SAMPLING_RATE)
    speechbrain = vad_inference_speechbrain(audio_paths[i], vad)

    silero = print_timestamps_silero(silero)
    speechbrain = print_timestamps_speechbrain(speechbrain)


    silero = merge_speech_segments(silero)
    speechbrain = merge_speech_segments(speechbrain)

    
    res_silero.append(silero)
    res_speechbrain.append(speechbrain)

# %%
rr.sort(reverse=True)

for index in rr:
    audio_paths.pop(index)
    label_paths.pop(index)
    annotated_segments.pop(index)

# %%
file_names = extract_filenames_as_string(label_paths)

save_multiple_speech_segments_as_text(res_silero, file_names, "/Users/saurabh/Documents/projects/Voice-Activity-Detection/data/bh_dataset/predicted_for_FE/silero")
save_multiple_speech_segments_as_text(res_speechbrain, file_names, "/Users/saurabh/Documents/projects/Voice-Activity-Detection/data/bh_dataset/predicted_for_FE/speechbrain")

# %%
import os

def load_filenames(file_path):
    """
    Reads the filenames from a text file.
    
    Args:
        file_path (str): Path to the file containing filenames.
        
    Returns:
        list: List of filenames as strings.
    """
    with open(file_path, 'r') as file:
        filenames = file.read().splitlines()
    return filenames

def read_file(file_path):
    """
    Reads the content of a file.
    
    Args:
        file_path (str): Path to the file to read.
        
    Returns:
        str: Content of the file as a string.
    """
    with open(file_path, 'r') as file:
        return file.read()

def find_and_compare_files(directories, filenames):
    """
    Finds matching files in three directories based on provided filenames and prints their content.
    
    Args:
        directories (list): List of directory paths.
        filenames (list): List of filenames to search for.
    """
    for filename in filenames:
        found_files = {}
        for directory in directories:
            file_path = os.path.join(directory, filename + '.txt')  # Construct the full file path
            if os.path.exists(file_path):
                found_files[directory] = read_file(file_path)
        
        if found_files:
            print(f"\nMatching file content for '{filename}':")
            for directory, content in found_files.items():
                print(f"\nDirectory: {directory}")
                print(f"Content of {filename}.txt:\n{content}")
        else:
            print(f"\nNo matching file found for '{filename}'.")

if __name__ == "__main__":
    # Input paths
    input_txt_path = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/evaluation/vad_bhData/name.txt"
    dir1 = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero"
    dir2 = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain"
    dir3 = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE"
    
    # Load the filenames from the input text file
    filenames = load_filenames(input_txt_path)
    
    # Directories to search for matching files
    directories = [dir1, dir2, dir3]
    
    # Find and compare files
    find_and_compare_files(directories, filenames)
# Out:
# Matching file content for '281474977585189':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474977585189.txt:
# 1.346000	7.102000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474977585189.txt:
# 1.380000	6.970000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474977585189.txt:
# S	1.35	1.77
#
#
# Matching file content for '281474977594045':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474977594045.txt:
# 1.666000	3.966000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474977594045.txt:
# 1.630000	3.900000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474977594045.txt:
# S	1.59	2.25
#
#
# Matching file content for '281474977648654':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474977648654.txt:
# 0.994000	4.926000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474977648654.txt:
# 1.030000	4.850000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474977648654.txt:
# S	0.6900000000000001	1.5300000000000002
#
#
# Matching file content for '281474977680938':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474977680938.txt:
# 1.122000	4.446000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474977680938.txt:
# 1.160000	4.460000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474977680938.txt:
# S	1.1400000000000001	1.8000000000000003
#
#
# Matching file content for '281474977682649':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474977682649.txt:
# 2.018000	5.342000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474977682649.txt:
# 2.040000	30.650000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474977682649.txt:
# S	1.92	2.37
#
#
# Matching file content for '281474978119084':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474978119084.txt:
# 1.250000	6.014000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474978119084.txt:
# 1.270000	5.960000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474978119084.txt:
# S	1.23	2.19
#
#
# Matching file content for '281474978176065':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474978176065.txt:
# 1.250000	7.102000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474978176065.txt:
# 1.270000	7.820000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474978176065.txt:
# S	1.2000000000000002	2.31
#
#
# Matching file content for '281474978272723':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474978272723.txt:
# 0.322000	7.330000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474978272723.txt:
# 0.120000	7.290000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474978272723.txt:
# S	0.6900000000000001	1.11
#
#
# Matching file content for '281474978311264':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474978311264.txt:
# 0.610000	2.910000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474978311264.txt:
# 0.650000	2.940000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474978311264.txt:
# S	0.6000000000000001	1.1400000000000001
#
#
# Matching file content for '281474978364078':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474978364078.txt:
# 0.514000	2.814000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474978364078.txt:
# 0.550000	2.780000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474978364078.txt:
# S	0.51	1.11
#
#
# Matching file content for '281474978501462':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474978501462.txt:
# 1.186000	5.886000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474978501462.txt:
# 1.210000	5.720000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474978501462.txt:
# S	1.2000000000000002	1.9500000000000002
#
#
# Matching file content for '281474978597492':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474978597492.txt:
# 0.930000	7.070000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474978597492.txt:
# 0.950000	6.970000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474978597492.txt:
# S	0.8999999999999999	1.56
#
#
# Matching file content for '281474979391394':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474979391394.txt:
# 0.482000	3.230000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474979391394.txt:
# 0.530000	3.160000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474979391394.txt:
# S	0.44999999999999996	0.78
#
#
# Matching file content for '281474979554146':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474979554146.txt:
# 0.418000	4.460000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474979554146.txt:
# 0.030000	4.420000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474979554146.txt:
# S	0.36	0.75
#
#
# Matching file content for '281474979746087':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474979746087.txt:
# 0.098000	4.094000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474979746087.txt:
# 0.100000	3.880000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474979746087.txt:
# S	0.09	0.42000000000000004
#
#
# Matching file content for '281474979755779':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474979755779.txt:
# 1.922000	5.630000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474979755779.txt:
# 1.310000	5.970000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474979755779.txt:
# S	1.92	2.73
#
#
# Matching file content for '281474979757662':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474979757662.txt:
# 0.418000	5.690000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474979757662.txt:
# 0.040000	5.510000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474979757662.txt:
# S	0.24	0.5700000000000001
#
#
# Matching file content for '281474979910755':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474979910755.txt:
# 1.794000	3.614000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474979910755.txt:
# 1.820000	3.460000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474979910755.txt:
# S	1.77	2.19
#
#
# Matching file content for '281474979960752':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474979960752.txt:
# 1.090000	5.630000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474979960752.txt:
# 0.170000	5.410000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474979960752.txt:
# S	1.08	1.5
#
#
# Matching file content for '281474980055383':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474980055383.txt:
# 1.314000	2.974000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474980055383.txt:
# 0.080000	2.950000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474980055383.txt:
# S	1.29	1.62
#
#
# Matching file content for '281474980060646':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474980060646.txt:
# 0.002000	3.518000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474980060646.txt:
# 1.070000	3.430000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474980060646.txt:
# S	1.0499999999999998	1.44
#
#
# Matching file content for '281474980263350':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474980263350.txt:
# 1.122000	4.222000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474980263350.txt:
# 0.950000	4.110000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474980263350.txt:
# S	0.9299999999999999	1.35
#
#
# Matching file content for '281474980270830':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474980270830.txt:
# 1.250000	5.246000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474980270830.txt:
# 1.290000	5.120000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474980270830.txt:
# S	1.26	1.62
#
#
# Matching file content for '281474980285786':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474980285786.txt:
# 1.186000	6.494000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474980285786.txt:
# 1.150000	6.500000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474980285786.txt:
# S	1.08	1.59
#
#
# Matching file content for '281474980293280':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474980293280.txt:
# 1.122000	6.302000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474980293280.txt:
# 1.140000	6.290000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474980293280.txt:
# S	0.81	6.27
#
#
# Matching file content for '281474980293309':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474980293309.txt:
# 0.674000	2.206000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474980293309.txt:
# 0.580000	2.200000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474980293309.txt:
# S	0.54	2.19
#
#
# Matching file content for '281474980294565':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474980294565.txt:
# 0.226000	3.020000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474980294565.txt:
# 0.060000	2.980000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474980294565.txt:
# S	0.36	2.91
#
#
# Matching file content for '281474980724207':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474980724207.txt:
# 0.194000	6.846000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474980724207.txt:
# 1.570000	6.970000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474980724207.txt:
# S	1.7399999999999998	2.1599999999999997
#
#
# Matching file content for '281474980903269':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474980903269.txt:
# 0.610000	6.010000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474980903269.txt:
# 0.590000	5.980000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474980903269.txt:
# S	0.63	1.05
#
#
# Matching file content for '281474981073733':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474981073733.txt:
# 1.122000	4.770000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474981073733.txt:
# 0.020000	4.730000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474981073733.txt:
# S	0.9299999999999999	1.38
#
#
# Matching file content for '281474981177984':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474981177984.txt:
# 1.250000	8.734000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474981177984.txt:
# 0.010000	8.700000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474981177984.txt:
# S	0.78	1.3800000000000001
#
#
# Matching file content for '281474981275143':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474981275143.txt:
# 0.450000	2.590000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474981275143.txt:
# 0.230000	2.460000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474981275143.txt:
# S	0.39	0.9
#
#
# Matching file content for '281474981282881':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474981282881.txt:
# 0.000000	7.294000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474981282881.txt:
# 1.410000	7.240000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474981282881.txt:
# S	1.35	2.0100000000000002
#
#
# Matching file content for '281474981388708':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474981388708.txt:
# 0.962000	6.238000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474981388708.txt:
# 0.010000	6.080000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474981388708.txt:
# S	0.81	1.29
#
#
# Matching file content for '281474981524203':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474981524203.txt:
# 0.418000	8.638000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474981524203.txt:
# 0.010000	8.570000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474981524203.txt:
# S	0.36	0.66
#
#
# Matching file content for '281474981690045':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474981690045.txt:
# 0.706000	4.862000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474981690045.txt:
# 0.790000	4.540000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474981690045.txt:
# S	0.66	1.05
#
#
# Matching file content for '281474981690648':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474981690648.txt:
# 0.354000	3.742000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474981690648.txt:
# 0.400000	3.670000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474981690648.txt:
# S	0.33	3.66
#
#
# Matching file content for '281474981828677':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474981828677.txt:
# 0.066000	6.570000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474981828677.txt:
# 1.400000	6.520000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474981828677.txt:
# S	1.32	1.8
#
#
# Matching file content for '281474981947948':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474981947948.txt:
# 0.898000	5.246000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474981947948.txt:
# 0.950000	5.010000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474981947948.txt:
# S	0.8999999999999999	5.04
#
#
# Matching file content for '281474981953576':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474981953576.txt:
# 1.538000	6.398000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474981953576.txt:
# 1.580000	6.540000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474981953576.txt:
# S	1.5	2.04
#
#
# Matching file content for '281474982211048':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982211048.txt:
# 0.546000	3.230000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982211048.txt:
# 0.040000	2.950000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982211048.txt:
# S	0.30000000000000004	0.7200000000000001
#
#
# Matching file content for '281474982216864':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982216864.txt:
# 0.322000	5.660000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982216864.txt:
# 0.910000	5.620000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982216864.txt:
# S	0.81	1.11
#
#
# Matching file content for '281474982223205':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982223205.txt:
# 0.994000	5.690000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982223205.txt:
# 1.030000	5.550000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982223205.txt:
# S	0.96	1.74
#
#
# Matching file content for '281474982292815':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982292815.txt:
# 0.738000	3.460000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982292815.txt:
# 0.800000	2.990000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982292815.txt:
# S	0.63	3.4499999999999997
#
#
# Matching file content for '281474982294187':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982294187.txt:
# 0.642000	5.278000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982294187.txt:
# 0.300000	5.150000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982294187.txt:
# S	0.63	1.44
#
#
# Matching file content for '281474982298411':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982298411.txt:
# 0.642000	9.342000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982298411.txt:
# 0.060000	9.330000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982298411.txt:
# S	0.63	1.17
#
#
# Matching file content for '281474982324123':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982324123.txt:
# 0.514000	3.480000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982324123.txt:
# 0.070000	3.440000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982324123.txt:
# S	0.42000000000000004	1.29
#
#
# Matching file content for '281474982395658':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982395658.txt:
# 0.578000	6.782000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982395658.txt:
# 0.420000	6.570000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982395658.txt:
# S	0.5700000000000001	1.4100000000000001
#
#
# Matching file content for '281474982399150':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982399150.txt:
# 0.706000	5.982000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982399150.txt:
# 0.060000	5.990000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982399150.txt:
# S	0.6900000000000001	0.9600000000000001
#
#
# Matching file content for '281474982500051':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982500051.txt:
# 0.290000	2.640000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982500051.txt:
# 0.000000	2.360000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982500051.txt:
# S	0.15000000000000002	0.45000000000000007
#
#
# Matching file content for '281474982581905':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982581905.txt:
# 0.290000	5.080000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982581905.txt:
# 0.040000	4.970000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982581905.txt:
# S	0.15000000000000002	0.66
#
#
# Matching file content for '281474982645154':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982645154.txt:
# 1.442000	6.814000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982645154.txt:
# 1.460000	6.650000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982645154.txt:
# S	1.44	1.95
#
#
# Matching file content for '281474982645381':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982645381.txt:
# 0.098000	3.870000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982645381.txt:
# 0.230000	3.870000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982645381.txt:
# S	0.44999999999999996	0.9299999999999999
#
#
# Matching file content for '281474982745387':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982745387.txt:
# 0.098000	5.860000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982745387.txt:
# 0.050000	5.810000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982745387.txt:
# S	0.8999999999999999	1.71
#
#
# Matching file content for '281474982756239':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982756239.txt:
# 1.218000	3.102000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982756239.txt:
# 1.190000	2.990000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982756239.txt:
# S	1.17	1.83
#
#
# Matching file content for '281474982801729':
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero
# Content of 281474982801729.txt:
# 0.162000	6.782000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain
# Content of 281474982801729.txt:
# 0.030000	6.730000	speech
#
#
# Directory: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE
# Content of 281474982801729.txt:
# S	0.6000000000000001	1.1700000000000002

# %%
import os

def load_filenames(file_path):
    """
    Reads the filenames from a text file.
    
    Args:
        file_path (str): Path to the file containing filenames.
        
    Returns:
        list: List of filenames as strings.
    """
    with open(file_path, 'r') as file:
        filenames = file.read().splitlines()
    return filenames

def clean_directories(directories, filenames):
    """
    Removes files from the directories that are not listed in the filenames.
    
    Args:
        directories (list): List of directory paths.
        filenames (list): List of filenames to keep.
    """
    for directory in directories:
        for file in os.listdir(directory):
            file_name, ext = os.path.splitext(file)
            if ext == '.txt' and file_name not in filenames:
                file_path = os.path.join(directory, file)
                os.remove(file_path)
                print(f"Removed: {file_path}")

if __name__ == "__main__":
    # Input paths
    input_txt_path = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/evaluation/vad_bhData/name.txt"
    dir1 = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/silero"
    dir2 = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/predicted_for_FE/speechbrain"
    dir3 = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans_for_FE"
    
    # Load the filenames from the input text file
    filenames = load_filenames(input_txt_path)
    
    # Directories to clean
    directories = [dir1, dir2, dir3]
    
    # Clean the directories by keeping only the files listed in the input file
    clean_directories(directories, filenames)

# %%
import os

def load_filenames(file_path):
    """
    Reads the filenames from a text file.
    
    Args:
        file_path (str): Path to the file containing filenames.
        
    Returns:
        list: List of filenames (without extension) as strings.
    """
    with open(file_path, 'r') as file:
        filenames = file.read().splitlines()
    return filenames

def clean_directory(directory, filenames, extension):
    """
    Removes files from the directory that are not listed in the filenames and have the given extension.
    
    Args:
        directory (str): Path to the directory to clean.
        filenames (list): List of filenames (without extension) to keep.
        extension (str): File extension to check (e.g., '.wav' or '.txt').
    """
    for file in os.listdir(directory):
        file_name, ext = os.path.splitext(file)
        if ext == extension and file_name not in filenames:
            file_path = os.path.join(directory, file)
            os.remove(file_path)
            print(f"Removed: {file_path}")

if __name__ == "__main__":
    # Input paths
    input_txt_path = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/evaluation/vad_bhData/name.txt"
    wav_dir = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_audio"
    txt_dir = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans"
    
    # Load the filenames from the input text file (without extensions)
    filenames = load_filenames(input_txt_path)
    
    # Clean the directories by keeping only the files listed in the input file
    clean_directory(wav_dir, filenames, '.wav')  # Clean .wav files
    clean_directory(txt_dir, filenames, '.txt')  # Clean .txt files
# Out:
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982330859.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474980729400.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977903187.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982649957.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982648679.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978100266.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981075344.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474980294565.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982587339.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978391062.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981073521.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981176854.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982584430.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982743841.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982856935.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982580520.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978104412.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982501765.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982399015.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978694071.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981073695.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982292815.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982645410.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981696318.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982392785.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982580109.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474979959938.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982746690.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982854868.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977657137.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978284655.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982125794.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982324168.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978391058.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982751338.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977646560.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474980906202.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982751675.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978957551.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982650621.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982484691.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978129899.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474980293309.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981073811.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981073805.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982828118.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981693638.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981963885.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982649472.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474980293280.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474979393649.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982142387.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977490104.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474979903891.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977544630.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982324134.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474979394255.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474980904501.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982800334.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474980907578.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982042631.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982720761.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977658515.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982656556.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982497601.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978285072.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981541259.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982590420.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981693204.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474979551557.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977490102.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978155610.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982577899.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982586486.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982647510.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977944491.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982209265.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474980903278.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474979565787.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981278880.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982647496.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982580159.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982644968.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981693235.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981690648.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977673370.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977520023.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981948002.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982731488.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982734080.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982488517.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978296401.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977748055.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982593450.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982582978.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982580216.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982645694.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982584716.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981808810.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978155591.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977519672.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981817360.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982593807.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981691440.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982583584.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982125407.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981377871.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982580098.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474979960755.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982645949.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982500063.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978326366.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978096178.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474979153327.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474979567249.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982752987.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978489324.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981696077.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982134493.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981947948.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982327127.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982580128.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977511688.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981275456.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982135001.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474978391051.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474983045183.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982052265.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982052305.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981960714.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982497279.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981819770.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474981370673.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977862560.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982210158.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474977678109.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982292832.txt
# Removed: /Users/saurabh/Documents/projects/Voice-Activity-Detection/testing/188_trans/281474982852368.txt

# %%
import os

def print_txt_files_content(directory_path):
    # Loop through all files in the directory
    for filename in os.listdir(directory_path):
        # Check if the file is a .txt file
        if filename.endswith(".txt"):
            file_path = os.path.join(directory_path, filename)
            print(f"Contents of {filename}:\n")
            # Open and read the file
            with open(file_path, 'r', encoding='utf-8') as file:
                content = file.read()
                print(content)
                print("\n" + "="*50 + "\n")  # Separator between files

# Replace 'your_directory_path' with the actual directory containing your .txt files
directory_path = "/Users/saurabh/Documents/projects/Voice-Activity-Detection/data/bh_dataset/188_samples/188_trans"
print_txt_files_content(directory_path)
# Out:
# Contents of 281474982330859.txt:
#
# 281474982330859	0.8999999999999999	1.65
# 281474982330859	1.6500000000000001	1.9500000000000002
# 281474982330859	1.9500000000000002	2.5500000000000003
# 281474982330859	2.55	2.9099999999999997
# 281474982330859	2.91	3.24
# 281474982330859	3.33	3.99
# 281474982330859	3.99	4.23
# 281474982330859	4.2299999999999995	4.8
# 281474982330859	4.800000000000001	5.4
# 281474982330859	5.4	5.94
#
#
# ==================================================
#
# Contents of 281474982801729.txt:
#
# 281474982801729	0.6000000000000001	1.1700000000000002
#
#
# ==================================================
#
# Contents of 281474980729400.txt:
#
# 281474980729400	0.72	1.32
# 281474980729400	1.32	1.4100000000000001
# 281474980729400	1.41	1.71
# 281474980729400	1.71	1.89
# 281474980729400	1.8900000000000001	2.2800000000000002
# 281474980729400	2.2800000000000002	2.49
# 281474980729400	2.4899999999999998	2.82
# 281474980729400	2.82	2.9699999999999998
# 281474980729400	2.9699999999999998	3.4499999999999997
# 281474980729400	3.4499999999999997	3.9899999999999998
# 281474980729400	4.0200000000000005	4.23
# 281474980729400	4.2299999999999995	4.6499999999999995
# 281474980729400	4.68	5.1
# 281474980729400	5.46	5.79
# 281474980729400	5.79	6.24
# 281474980729400	6.24	6.6000000000000005
# 281474980729400	6.6000000000000005	6.9
# 281474980729400	6.93	7.08
# 281474980729400	7.08	7.38
# 281474980729400	7.41	7.71
#
#
# ==================================================
#
# Contents of 281474977903187.txt:
#
# 281474977903187	0.03	0.12
# 281474977903187	0.12	0.3
# 281474977903187	0.30000000000000004	0.75
# 281474977903187	0.78	1.29
#
#
# ==================================================
#
# Contents of 281474982649957.txt:
#
# 281474982649957	1.2000000000000002	1.6500000000000001
# 281474982649957	1.6500000000000001	2.0700000000000003
# 281474982649957	2.07	2.3099999999999996
# 281474982649957	2.73	3.33
# 281474982649957	3.33	3.7800000000000002
# 281474982649957	3.7800000000000002	4.140000000000001
# 281474982649957	4.14	4.619999999999999
#
#
# ==================================================
#
# Contents of 281474982211048.txt:
#
# 281474982211048	0.30000000000000004	0.7200000000000001
#
#
# ==================================================
#
# Contents of 281474978311264.txt:
#
# 281474978311264	0.6000000000000001	1.1400000000000001
#
#
# ==================================================
#
# Contents of 281474982648679.txt:
#
# 281474982648679	0.48	0.87
# 281474982648679	0.8699999999999999	1.3199999999999998
# 281474982648679	1.32	1.53
# 281474982648679	1.53	1.83
# 281474982648679	1.83	2.31
# 281474982648679	2.37	2.58
# 281474982648679	3.06	3.3600000000000003
# 281474982648679	3.3600000000000003	3.8100000000000005
# 281474982648679	3.81	3.96
# 281474982648679	3.96	4.29
# 281474982648679	4.29	4.59
# 281474982648679	4.59	5.1
#
#
# ==================================================
#
# Contents of 281474978100266.txt:
#
# 281474978100266	0.9299999999999999	1.65
# 281474978100266	1.6500000000000001	1.86
# 281474978100266	1.8599999999999999	2.2199999999999998
# 281474978100266	2.2199999999999998	2.61
# 281474978100266	2.61	2.8499999999999996
# 281474978100266	2.8499999999999996	3.3599999999999994
# 281474978100266	3.3600000000000003	3.6900000000000004
# 281474978100266	3.69	4.02
# 281474978100266	4.0200000000000005	4.2
# 281474978100266	4.199999999999999	4.289999999999999
# 281474978100266	4.29	4.77
# 281474978100266	4.7700000000000005	5.25
#
#
# ==================================================
#
# Contents of 281474981075344.txt:
#
# 281474981075344	0.42000000000000004	0.6900000000000001
# 281474981075344	0.6900000000000001	0.9000000000000001
# 281474981075344	0.8999999999999999	1.23
# 281474981075344	1.29	1.3800000000000001
# 281474981075344	1.41	1.83
# 281474981075344	1.83	2.16
# 281474981075344	2.16	2.58
# 281474981075344	2.58	3.1500000000000004
# 281474981075344	3.1500000000000004	3.3000000000000003
# 281474981075344	3.33	3.84
# 281474981075344	3.84	3.9
# 281474981075344	4.050000000000001	5.07
# 281474981075344	5.46	7.05
# 281474981075344	7.26	7.56
# 281474981075344	7.59	7.9799999999999995
#
#
# ==================================================
#
# Contents of 281474980294565.txt:
#
# 281474980294565	0.36	0.8099999999999999
# 281474980294565	0.81	0.9600000000000001
# 281474980294565	0.96	1.38
# 281474980294565	1.3800000000000001	1.5300000000000002
# 281474980294565	1.53	1.92
# 281474980294565	1.92	2.46
# 281474980294565	2.46	2.58
# 281474980294565	2.58	2.91
#
#
# ==================================================
#
# Contents of 281474982587339.txt:
#
# 281474982587339	0.78	1.44
# 281474982587339	1.44	1.65
# 281474982587339	1.6500000000000001	1.86
# 281474982587339	1.8599999999999999	2.37
#
#
# ==================================================
#
# Contents of 281474978391062.txt:
#
# 281474978391062	0.36	0.84
# 281474978391062	0.8400000000000001	1.02
# 281474978391062	1.02	1.5
# 281474978391062	1.5	1.8
# 281474978391062	1.7999999999999998	1.92
# 281474978391062	1.92	2.16
# 281474978391062	2.16	2.25
# 281474978391062	2.25	2.67
#
#
# ==================================================
#
# Contents of 281474981073521.txt:
#
# 281474981073521	1.1400000000000001	1.5300000000000002
# 281474981073521	1.53	1.74
# 281474981073521	1.7399999999999998	2.1599999999999997
# 281474981073521	2.16	2.37
# 281474981073521	2.37	2.85
# 281474981073521	2.8499999999999996	3.42
# 281474981073521	3.42	3.69
# 281474981073521	3.69	3.9299999999999997
# 281474981073521	3.96	4.5
# 281474981073521	4.5	5.4
# 281474981073521	5.699999999999999	6.18
# 281474981073521	6.18	6.66
# 281474981073521	6.66	7.140000000000001
# 281474981073521	7.17	7.41
#
#
# ==================================================
#
# Contents of 281474981176854.txt:
#
# 281474981176854	0.36	0.93
# 281474981176854	0.9299999999999999	1.14
# 281474981176854	1.1400000000000001	1.62
# 281474981176854	1.6800000000000002	2.1900000000000004
# 281474981176854	2.19	2.58
# 281474981176854	2.58	3.0300000000000002
#
#
# ==================================================
#
# Contents of 281474978119084.txt:
#
# 281474978119084	1.23	2.19
#
#
# ==================================================
#
# Contents of 281474982584430.txt:
#
# 281474982584430	0.6000000000000001	1.11
# 281474982584430	1.1099999999999999	1.3499999999999999
# 281474982584430	1.35	1.9200000000000002
# 281474982584430	1.92	2.46
#
#
# ==================================================
#
# Contents of 281474980055383.txt:
#
# 281474980055383	1.29	1.62
#
#
# ==================================================
#
# Contents of 281474977680938.txt:
#
# 281474977680938	1.1400000000000001	1.8000000000000003
#
#
# ==================================================
#
# Contents of 281474982743841.txt:
#
# 281474982743841	0.48	0.96
# 281474982743841	0.96	1.17
# 281474982743841	1.2000000000000002	1.56
# 281474982743841	1.56	1.83
# 281474982743841	1.83	2.34
# 281474982743841	2.34	2.73
# 281474982743841	2.73	3.39
#
#
# ==================================================
#
# Contents of 281474982223205.txt:
#
# 281474982223205	0.96	1.74
#
#
# ==================================================
#
# Contents of 281474982856935.txt:
#
# 281474982856935	0.30000000000000004	0.8400000000000001
# 281474982856935	0.8400000000000001	1.1700000000000002
# 281474982856935	1.17	1.71
# 281474982856935	1.71	2.19
# 281474982856935	2.19	2.55
# 281474982856935	2.55	2.9699999999999998
#
#
# ==================================================
#
# Contents of 281474979757662.txt:
#
# 281474979757662	0.24	0.5700000000000001
#
#
# ==================================================
#
# Contents of 281474982580520.txt:
#
# 281474982580520	0.6900000000000001	1.2600000000000002
# 281474982580520	1.26	1.74
# 281474982580520	1.7399999999999998	2.2199999999999998
# 281474982580520	2.2800000000000002	2.9400000000000004
# 281474982580520	3.0	3.45
# 281474982580520	3.4499999999999997	3.8999999999999995
# 281474982580520	3.9000000000000004	4.2
# 281474982580520	4.199999999999999	4.4399999999999995
# 281474982580520	4.47	5.04
#
#
# ==================================================
#
# Contents of 281474978104412.txt:
#
# 281474978104412	0.75	1.92
# 281474978104412	2.2199999999999998	2.82
# 281474978104412	2.82	3.48
# 281474978104412	4.17	5.3100000000000005
# 281474978104412	5.3100000000000005	5.670000000000001
# 281474978104412	5.67	6.12
#
#
# ==================================================
#
# Contents of 281474982501765.txt:
#
# 281474982501765	1.02	1.62
# 281474982501765	1.62	2.22
# 281474982501765	2.2199999999999998	2.4899999999999998
# 281474982501765	2.4899999999999998	2.8499999999999996
# 281474982501765	2.8499999999999996	3.42
# 281474982501765	3.54	3.9
# 281474982501765	3.93	4.3500000000000005
#
#
# ==================================================
#
# Contents of 281474982399015.txt:
#
# 281474982399015	0.5700000000000001	0.93
# 281474982399015	0.9299999999999999	1.47
# 281474982399015	1.47	1.95
# 281474982399015	1.9500000000000002	2.37
# 281474982399015	2.58	3.21
# 281474982399015	3.5999999999999996	4.26
# 281474982399015	4.32	4.470000000000001
# 281474982399015	5.9399999999999995	6.3
#
#
# ==================================================
#
# Contents of 281474978694071.txt:
#
# 281474978694071	1.1400000000000001	1.8000000000000003
# 281474978694071	2.46	3.0
# 281474978694071	3.0	3.7199999999999998
# 281474978694071	3.99	4.2
# 281474978694071	4.199999999999999	4.6499999999999995
# 281474978694071	4.65	4.86
# 281474978694071	4.86	5.04
# 281474978694071	5.04	5.4
# 281474978694071	5.64	6.029999999999999
# 281474978694071	6.0600000000000005	6.45
# 281474978694071	6.48	6.9
#
#
# ==================================================
#
# Contents of 281474981073695.txt:
#
# 281474981073695	0.48	1.23
# 281474981073695	1.23	1.68
# 281474981073695	1.71	2.1
# 281474981073695	2.0999999999999996	2.7299999999999995
# 281474981073695	2.73	2.9699999999999998
# 281474981073695	2.9699999999999998	3.4499999999999997
# 281474981073695	3.51	3.9
# 281474981073695	3.9000000000000004	4.470000000000001
# 281474981073695	4.47	4.83
#
#
# ==================================================
#
# Contents of 281474982292815.txt:
#
# 281474982292815	0.63	1.05
# 281474982292815	1.0499999999999998	1.38
# 281474982292815	1.3800000000000001	1.5
# 281474982292815	1.5	1.98
# 281474982292815	2.04	2.16
# 281474982292815	2.16	2.7300000000000004
# 281474982292815	2.73	3.06
# 281474982292815	3.09	3.4499999999999997
#
#
# ==================================================
#
# Contents of 281474982645410.txt:
#
# 281474982645410	0.51	0.93
# 281474982645410	0.9299999999999999	1.08
# 281474982645410	1.1099999999999999	1.4699999999999998
# 281474982645410	1.47	1.74
# 281474982645410	1.77	2.0700000000000003
# 281474982645410	2.07	2.34
# 281474982645410	2.34	2.4899999999999998
# 281474982645410	2.4899999999999998	2.88
#
#
# ==================================================
#
# Contents of 281474981696318.txt:
#
# 281474981696318	2.4000000000000004	3.0000000000000004
# 281474981696318	3.0	3.33
# 281474981696318	3.33	3.48
# 281474981696318	3.4799999999999995	3.9599999999999995
# 281474981696318	3.96	4.23
# 281474981696318	4.2299999999999995	4.409999999999999
# 281474981696318	4.41	4.8
# 281474981696318	4.800000000000001	5.19
# 281474981696318	5.1899999999999995	5.489999999999999
# 281474981696318	5.49	5.76
#
#
# ==================================================
#
# Contents of 281474982392785.txt:
#
# 281474982392785	0.39	0.6900000000000001
# 281474982392785	0.6900000000000001	0.9000000000000001
# 281474982392785	0.8999999999999999	1.0499999999999998
# 281474982392785	1.0499999999999998	1.38
# 281474982392785	1.3800000000000001	1.6800000000000002
# 281474982392785	1.6800000000000002	1.9200000000000002
# 281474982392785	1.92	2.2199999999999998
# 281474982392785	2.2199999999999998	2.3699999999999997
# 281474982392785	2.4000000000000004	2.6700000000000004
# 281474982392785	2.67	3.09
# 281474982392785	3.2700000000000005	3.7500000000000004
# 281474982392785	3.75	3.84
# 281474982392785	3.84	4.05
#
#
# ==================================================
#
# Contents of 281474982580109.txt:
#
# 281474982580109	0.33	0.69
# 281474982580109	0.6900000000000001	0.8400000000000001
# 281474982580109	0.8400000000000001	1.1700000000000002
# 281474982580109	1.17	1.26
# 281474982580109	1.26	1.6800000000000002
# 281474982580109	1.6800000000000002	2.0100000000000002
# 281474982580109	2.0100000000000002	2.16
# 281474982580109	2.25	2.4
# 281474982580109	2.4000000000000004	2.5800000000000005
# 281474982580109	2.58	2.88
# 281474982580109	2.88	3.15
#
#
# ==================================================
#
# Contents of 281474979959938.txt:
#
# 281474979959938	0.42000000000000004	0.87
# 281474979959938	0.8699999999999999	1.29
# 281474979959938	1.29	2.13
# 281474979959938	2.13	2.79
# 281474979959938	3.5999999999999996	4.109999999999999
# 281474979959938	4.11	4.53
# 281474979959938	4.53	5.04
#
#
# ==================================================
#
# Contents of 281474982746690.txt:
#
# 281474982746690	0.06	0.42
# 281474982746690	0.44999999999999996	0.6
# 281474982746690	0.6000000000000001	1.05
# 281474982746690	1.0499999999999998	1.5299999999999998
# 281474982746690	1.53	1.8900000000000001
# 281474982746690	1.8900000000000001	2.04
# 281474982746690	2.04	2.52
#
#
# ==================================================
#
# Contents of 281474982854868.txt:
#
# 281474982854868	0.5700000000000001	0.93
# 281474982854868	0.9299999999999999	1.02
# 281474982854868	1.02	1.32
# 281474982854868	1.32	1.44
# 281474982854868	1.44	1.8599999999999999
# 281474982854868	1.8599999999999999	2.04
# 281474982854868	2.04	2.55
#
#
# ==================================================
#
# Contents of 281474977657137.txt:
#
# 281474977657137	5.01	5.88
# 281474977657137	5.88	6.24
# 281474977657137	6.24	6.69
# 281474977657137	6.6899999999999995	6.8999999999999995
# 281474977657137	6.8999999999999995	7.199999999999999
# 281474977657137	7.199999999999999	7.35
# 281474977657137	7.3500000000000005	7.680000000000001
# 281474977657137	7.709999999999999	8.04
#
#
# ==================================================
#
# Contents of 281474981073733.txt:
#
# 281474981073733	0.9299999999999999	1.38
#
#
# ==================================================
#
# Contents of 281474978284655.txt:
#
# 281474978284655	0.44999999999999996	1.02
# 281474978284655	1.02	1.59
# 281474978284655	1.59	2.22
#
#
# ==================================================
#
# Contents of 281474982125794.txt:
#
# 281474982125794	1.53	2.76
# 281474982125794	2.88	3.3
# 281474982125794	3.51	4.38
# 281474982125794	4.38	4.8
# 281474982125794	4.800000000000001	5.250000000000001
# 281474982125794	5.28	5.91
# 281474982125794	6.27	6.72
# 281474982125794	6.720000000000001	7.23
# 281474982125794	7.23	7.74
# 281474982125794	7.74	8.25
# 281474982125794	8.28	8.7
#
#
# ==================================================
#
# Contents of 281474982216864.txt:
#
# 281474982216864	0.81	1.11
#
#
# ==================================================
#
# Contents of 281474982324168.txt:
#
# 281474982324168	0.72	1.32
# 281474982324168	1.32	1.5
# 281474982324168	1.56	2.1
# 281474982324168	2.0999999999999996	2.3099999999999996
# 281474982324168	2.34	2.82
# 281474982324168	2.8499999999999996	3.1499999999999995
# 281474982324168	3.18	3.63
# 281474982324168	3.63	4.14
# 281474982324168	4.14	4.6499999999999995
# 281474982324168	4.65	5.04
# 281474982324168	5.07	5.5200000000000005
#
#
# ==================================================
#
# Contents of 281474978391058.txt:
#
# 281474978391058	0.44999999999999996	0.72
# 281474978391058	0.72	1.1099999999999999
# 281474978391058	1.1099999999999999	1.2899999999999998
# 281474978391058	1.29	1.71
# 281474978391058	1.92	2.16
# 281474978391058	2.16	2.3400000000000003
# 281474978391058	2.73	2.88
# 281474978391058	2.91	3.27
# 281474978391058	3.2700000000000005	3.6300000000000003
#
#
# ==================================================
#
# Contents of 281474982751338.txt:
#
# 281474982751338	0.99	1.56
# 281474982751338	1.56	1.92
# 281474982751338	1.92	2.16
# 281474982751338	2.16	2.5500000000000003
# 281474982751338	2.55	2.88
# 281474982751338	2.88	3.0
# 281474982751338	3.0	3.69
#
#
# ==================================================
#
# Contents of 281474977646560.txt:
#
# 281474977646560	1.17	1.68
# 281474977646560	1.6800000000000002	2.1
# 281474977646560	2.16	2.49
# 281474977646560	2.4899999999999998	2.8499999999999996
# 281474977646560	3.0	3.48
# 281474977646560	3.5999999999999996	4.26
# 281474977646560	4.26	5.13
#
#
# ==================================================
#
# Contents of 281474980906202.txt:
#
# 281474980906202	0.75	1.5
# 281474980906202	1.5	1.8900000000000001
# 281474980906202	1.8900000000000001	2.22
# 281474980906202	2.25	2.64
# 281474980906202	2.64	3.1500000000000004
#
#
# ==================================================
#
# Contents of 281474982751675.txt:
#
# 281474982751675	0.12	0.39
# 281474982751675	0.39	0.93
# 281474982751675	0.9299999999999999	1.14
# 281474982751675	1.1400000000000001	1.32
# 281474982751675	1.32	1.56
# 281474982751675	1.59	1.71
#
#
# ==================================================
#
# Contents of 281474982500051.txt:
#
# 281474982500051	0.15000000000000002	0.45000000000000007
#
#
# ==================================================
#
# Contents of 281474978957551.txt:
#
# 281474978957551	0.63	1.38
# 281474978957551	1.3800000000000001	1.56
# 281474978957551	1.56	2.13
# 281474978957551	2.19	2.49
# 281474978957551	2.4899999999999998	3.0
# 281474978957551	3.0	3.21
# 281474978957551	3.21	3.66
# 281474978957551	3.66	4.08
# 281474978957551	4.08	4.53
# 281474978957551	4.53	4.95
#
#
# ==================================================
#
# Contents of 281474982650621.txt:
#
# 281474982650621	0.42000000000000004	0.7200000000000001
# 281474982650621	0.72	1.08
# 281474982650621	1.08	1.53
# 281474982650621	1.56	1.8900000000000001
# 281474982650621	1.8900000000000001	2.31
# 281474982650621	2.31	2.85
#
#
# ==================================================
#
# Contents of 281474982484691.txt:
#
# 281474982484691	0.75	1.05
# 281474982484691	1.0499999999999998	1.4699999999999998
# 281474982484691	1.5	1.8900000000000001
# 281474982484691	1.8900000000000001	2.16
# 281474982484691	2.16	2.64
# 281474982484691	2.64	2.7
#
#
# ==================================================
#
# Contents of 281474978129899.txt:
#
# 281474978129899	0.33	1.05
# 281474978129899	1.0499999999999998	1.38
# 281474978129899	1.3800000000000001	1.8900000000000001
# 281474978129899	2.4899999999999998	3.0
# 281474978129899	3.0	3.54
# 281474978129899	3.54	3.84
# 281474978129899	5.49	5.79
# 281474978129899	5.79	6.03
#
#
# ==================================================
#
# Contents of 281474981828677.txt:
#
# 281474981828677	1.32	1.8
#
#
# ==================================================
#
# Contents of 281474980293309.txt:
#
# 281474980293309	0.54	1.02
# 281474980293309	1.02	1.4100000000000001
# 281474980293309	1.41	1.68
# 281474980293309	1.6800000000000002	1.83
# 281474980293309	1.83	2.19
#
#
# ==================================================
#
# Contents of 281474981073811.txt:
#
# 281474981073811	0.63	1.17
# 281474981073811	1.17	1.38
# 281474981073811	1.3800000000000001	1.8000000000000003
# 281474981073811	1.7999999999999998	2.01
# 281474981073811	2.0100000000000002	2.49
# 281474981073811	2.4899999999999998	2.8499999999999996
# 281474981073811	2.8499999999999996	3.1799999999999997
# 281474981073811	3.24	3.66
# 281474981073811	3.66	3.99
# 281474981073811	4.050000000000001	4.200000000000001
# 281474981073811	4.199999999999999	4.619999999999999
#
#
# ==================================================
#
# Contents of 281474981073805.txt:
#
# 281474981073805	0.81	1.4100000000000001
# 281474981073805	1.41	1.98
# 281474981073805	2.0100000000000002	2.2800000000000002
# 281474981073805	2.34	2.55
# 281474981073805	2.55	3.15
# 281474981073805	3.63	3.96
# 281474981073805	3.96	4.65
# 281474981073805	5.07	5.550000000000001
# 281474981073805	5.550000000000001	5.82
# 281474981073805	5.82	6.24
# 281474981073805	6.24	6.63
# 281474981073805	6.63	6.87
# 281474981073805	6.87	7.29
# 281474981073805	7.290000000000001	7.680000000000001
# 281474981073805	7.68	8.25
#
#
# ==================================================
#
# Contents of 281474982828118.txt:
#
# 281474982828118	0.5700000000000001	0.9000000000000001
# 281474982828118	0.8999999999999999	1.2
# 281474982828118	1.2000000000000002	1.4400000000000002
# 281474982828118	1.44	1.74
# 281474982828118	1.7399999999999998	2.01
# 281474982828118	2.0100000000000002	2.0700000000000003
# 281474982828118	2.07	2.37
# 281474982828118	2.37	2.52
# 281474982828118	2.52	2.76
# 281474982828118	2.79	2.97
# 281474982828118	2.9699999999999998	3.1199999999999997
# 281474982828118	3.12	3.3600000000000003
# 281474982828118	3.3600000000000003	3.4200000000000004
# 281474982828118	3.42	3.69
# 281474982828118	3.69	3.75
# 281474982828118	3.7800000000000002	4.050000000000001
# 281474982828118	4.050000000000001	4.32
# 281474982828118	4.32	4.62
# 281474982828118	4.62	4.83
# 281474982828118	5.07	5.25
# 281474982828118	5.25	5.49
#
#
# ==================================================
#
# Contents of 281474981693638.txt:
#
# 281474981693638	0.39	0.84
# 281474981693638	0.8400000000000001	1.1400000000000001
# 281474981693638	1.1400000000000001	1.7100000000000002
# 281474981693638	1.71	1.89
# 281474981693638	1.8900000000000001	2.31
# 281474981693638	2.34	2.58
# 281474981693638	2.58	2.88
# 281474981693638	2.88	3.27
# 281474981693638	3.33	3.54
# 281474981693638	3.54	3.87
#
#
# ==================================================
#
# Contents of 281474980903269.txt:
#
# 281474980903269	0.63	1.05
#
#
# ==================================================
#
# Contents of 281474979910755.txt:
#
# 281474979910755	1.77	2.19
#
#
# ==================================================
#
# Contents of 281474981963885.txt:
#
# 281474981963885	0.63	1.5299999999999998
# 281474981963885	1.77	2.04
# 281474981963885	2.04	2.79
# 281474981963885	2.88	3.36
# 281474981963885	3.81	4.41
# 281474981963885	4.74	5.01
# 281474981963885	5.01	5.46
# 281474981963885	5.5200000000000005	6.42
# 281474981963885	6.540000000000001	7.200000000000001
# 281474981963885	7.199999999999999	7.529999999999999
# 281474981963885	7.68	7.83
# 281474981963885	7.86	8.370000000000001
# 281474981963885	8.370000000000001	8.670000000000002
# 281474981963885	8.67	9.12
# 281474981963885	9.120000000000001	9.63
# 281474981963885	9.629999999999999	9.78
# 281474981963885	9.78	10.17
# 281474981963885	10.5	10.8
#
#
# ==================================================
#
# Contents of 281474982649472.txt:
#
# 281474982649472	0.8400000000000001	1.56
# 281474982649472	1.56	1.83
# 281474982649472	1.83	2.2800000000000002
# 281474982649472	2.2800000000000002	2.7600000000000002
# 281474982649472	2.7600000000000002	3.45
#
#
# ==================================================
#
# Contents of 281474980293280.txt:
#
# 281474980293280	0.81	1.77
# 281474980293280	1.77	1.95
# 281474980293280	1.9500000000000002	2.3400000000000003
# 281474980293280	2.52	3.06
# 281474980293280	3.06	3.3600000000000003
# 281474980293280	3.5999999999999996	3.9899999999999998
# 281474980293280	3.99	4.44
# 281474980293280	4.47	4.77
# 281474980293280	5.49	5.76
# 281474980293280	5.76	5.85
# 281474980293280	5.85	6.09
# 281474980293280	6.09	6.27
#
#
# ==================================================
#
# Contents of 281474979393649.txt:
#
# 281474979393649	0.5700000000000001	1.1700000000000002
# 281474979393649	1.17	1.3499999999999999
# 281474979393649	1.35	1.71
# 281474979393649	1.71	2.13
# 281474979393649	2.13	2.55
#
#
# ==================================================
#
# Contents of 281474981690045.txt:
#
# 281474981690045	0.66	1.05
#
#
# ==================================================
#
# Contents of 281474982142387.txt:
#
# 281474982142387	0.36	0.84
# 281474982142387	0.8400000000000001	1.4100000000000001
# 281474982142387	1.41	1.68
# 281474982142387	1.7399999999999998	2.04
# 281474982142387	2.04	2.6100000000000003
# 281474982142387	2.61	3.15
# 281474982142387	3.1500000000000004	3.7200000000000006
# 281474982142387	3.75	4.02
# 281474982142387	4.0200000000000005	4.470000000000001
# 281474982142387	4.5	5.01
#
#
# ==================================================
#
# Contents of 281474977490104.txt:
#
# 281474977490104	1.08	1.59
# 281474977490104	1.59	1.9200000000000002
# 281474977490104	1.92	2.28
# 281474977490104	2.2800000000000002	2.7600000000000002
# 281474977490104	2.7600000000000002	2.9400000000000004
# 281474977490104	2.94	3.33
# 281474977490104	3.4499999999999997	3.78
# 281474977490104	3.7800000000000002	3.9000000000000004
# 281474977490104	3.93	4.44
# 281474977490104	4.4399999999999995	4.949999999999999
# 281474977490104	4.949999999999999	5.31
# 281474977490104	5.3100000000000005	5.61
# 281474977490104	5.64	5.91
#
#
# ==================================================
#
# Contents of 281474979903891.txt:
#
# 281474979903891	1.77	2.46
# 281474979903891	2.46	2.82
# 281474979903891	2.82	3.09
# 281474979903891	3.09	3.63
# 281474979903891	3.63	4.109999999999999
# 281474979903891	4.11	4.41
# 281474979903891	4.41	4.74
# 281474979903891	4.74	5.28
#
#
# ==================================================
#
# Contents of 281474977544630.txt:
#
# 281474977544630	0.96	1.71
# 281474977544630	1.7399999999999998	2.4299999999999997
# 281474977544630	2.43	2.64
# 281474977544630	2.64	2.97
# 281474977544630	2.9699999999999998	3.2399999999999998
# 281474977544630	3.24	3.6300000000000003
# 281474977544630	3.63	4.05
# 281474977544630	4.08	4.59
# 281474977544630	4.62	4.8
# 281474977544630	4.800000000000001	5.160000000000001
# 281474977544630	5.16	5.58
#
#
# ==================================================
#
# Contents of 281474982395658.txt:
#
# 281474982395658	0.5700000000000001	1.4100000000000001
#
#
# ==================================================
#
# Contents of 281474981524203.txt:
#
# 281474981524203	0.36	0.66
#
#
# ==================================================
#
# Contents of 281474978501462.txt:
#
# 281474978501462	1.2000000000000002	1.9500000000000002
#
#
# ==================================================
#
# Contents of 281474981953576.txt:
#
# 281474981953576	1.5	2.04
#
#
# ==================================================
#
# Contents of 281474982324134.txt:
#
# 281474982324134	1.29	1.86
# 281474982324134	1.92	2.34
# 281474982324134	2.37	2.8200000000000003
# 281474982324134	2.82	3.0
# 281474982324134	3.0	3.42
# 281474982324134	3.42	3.84
# 281474982324134	3.93	4.95
# 281474982324134	4.949999999999999	5.1899999999999995
# 281474982324134	5.1899999999999995	5.67
# 281474982324134	5.67	6.27
# 281474982324134	6.6899999999999995	7.4399999999999995
# 281474982324134	7.5600000000000005	8.07
# 281474982324134	8.07	8.43
# 281474982324134	8.459999999999999	8.76
# 281474982324134	8.76	9.03
# 281474982324134	9.06	9.24
# 281474982324134	9.24	9.63
# 281474982324134	9.66	10.08
#
#
# ==================================================
#
# Contents of 281474979394255.txt:
#
# 281474979394255	0.5700000000000001	0.9000000000000001
# 281474979394255	0.8999999999999999	1.17
# 281474979394255	1.17	1.3199999999999998
# 281474979394255	1.3800000000000001	1.7100000000000002
# 281474979394255	1.7399999999999998	2.0999999999999996
# 281474979394255	2.0999999999999996	2.55
#
#
# ==================================================
#
# Contents of 281474980904501.txt:
#
# 281474980904501	0.24	0.99
# 281474980904501	0.99	1.23
# 281474980904501	1.23	1.8599999999999999
# 281474980904501	2.2800000000000002	2.64
# 281474980904501	2.67	2.82
# 281474980904501	2.82	3.09
# 281474980904501	3.09	3.27
# 281474980904501	3.2700000000000005	3.5400000000000005
# 281474980904501	3.57	3.84
#
#
# ==================================================
#
# Contents of 281474982800334.txt:
#
# 281474982800334	0.63	0.9
# 281474982800334	0.8999999999999999	1.2599999999999998
# 281474982800334	1.29	1.71
# 281474982800334	1.71	2.16
# 281474982800334	2.25	2.85
# 281474982800334	3.42	3.99
# 281474982800334	3.99	4.65
#
#
# ==================================================
#
# Contents of 281474980907578.txt:
#
# 281474980907578	0.51	1.38
# 281474980907578	1.56	1.86
# 281474980907578	1.92	2.34
# 281474980907578	2.94	3.27
# 281474980907578	3.2700000000000005	3.7800000000000002
# 281474980907578	3.84	3.96
# 281474980907578	3.96	4.38
# 281474980907578	4.38	4.83
# 281474980907578	5.16	5.5200000000000005
# 281474980907578	5.5200000000000005	6.24
# 281474980907578	6.27	6.81
# 281474980907578	6.87	7.23
# 281474980907578	7.6499999999999995	8.28
# 281474980907578	8.28	8.43
# 281474980907578	8.43	8.879999999999999
# 281474980907578	8.879999999999999	9.149999999999999
# 281474980907578	9.149999999999999	9.299999999999999
#
#
# ==================================================
#
# Contents of 281474982042631.txt:
#
# 281474982042631	0.27	0.81
# 281474982042631	0.81	0.93
# 281474982042631	0.9299999999999999	1.2
# 281474982042631	1.2000000000000002	1.5300000000000002
# 281474982042631	1.56	2.0700000000000003
# 281474982042631	2.07	2.0999999999999996
# 281474982042631	2.0999999999999996	2.4899999999999998
#
#
# ==================================================
#
# Contents of 281474982720761.txt:
#
# 281474982720761	0.66	1.23
# 281474982720761	1.23	1.38
# 281474982720761	1.3800000000000001	1.8000000000000003
# 281474982720761	1.7999999999999998	2.04
# 281474982720761	2.04	2.31
# 281474982720761	2.31	2.58
# 281474982720761	2.58	2.94
# 281474982720761	2.94	3.12
# 281474982720761	3.12	3.5700000000000003
#
#
# ==================================================
#
# Contents of 281474981282881.txt:
#
# 281474981282881	1.35	2.0100000000000002
#
#
# ==================================================
#
# Contents of 281474977658515.txt:
#
# 281474977658515	0.75	1.02
# 281474977658515	1.02	1.44
# 281474977658515	1.44	1.5899999999999999
# 281474977658515	1.59	2.0700000000000003
# 281474977658515	2.07	2.2199999999999998
# 281474977658515	2.2199999999999998	2.5799999999999996
# 281474977658515	2.61	3.09
#
#
# ==================================================
#
# Contents of 281474982656556.txt:
#
# 281474982656556	0.27	0.6000000000000001
# 281474982656556	0.6000000000000001	0.78
# 281474982656556	0.78	1.11
# 281474982656556	1.1099999999999999	1.3199999999999998
# 281474982656556	1.32	1.6800000000000002
# 281474982656556	1.6800000000000002	1.86
# 281474982656556	1.8599999999999999	2.19
# 281474982656556	2.19	2.73
# 281474982656556	2.7600000000000002	3.0900000000000003
# 281474982656556	3.09	3.5999999999999996
# 281474982656556	3.63	4.109999999999999
# 281474982656556	4.11	4.380000000000001
# 281474982656556	4.38	4.83
# 281474982656556	4.83	5.16
# 281474982656556	5.16	5.49
#
#
# ==================================================
#
# Contents of 281474982497601.txt:
#
# 281474982497601	0.63	1.05
# 281474982497601	1.08	1.1700000000000002
# 281474982497601	1.17	1.47
# 281474982497601	1.47	1.62
# 281474982497601	1.62	1.8
# 281474982497601	1.7999999999999998	2.13
#
#
# ==================================================
#
# Contents of 281474978285072.txt:
#
# 281474978285072	0.42000000000000004	0.9
# 281474978285072	0.8999999999999999	1.1099999999999999
# 281474978285072	1.1099999999999999	1.23
# 281474978285072	1.23	1.5
# 281474978285072	1.5	1.83
# 281474978285072	1.83	2.19
#
#
# ==================================================
#
# Contents of 281474982324123.txt:
#
# 281474982324123	0.42000000000000004	1.29
#
#
# ==================================================
#
# Contents of 281474981541259.txt:
#
# 281474981541259	3.5999999999999996	4.02
# 281474981541259	4.800000000000001	5.670000000000001
# 281474981541259	5.67	6.36
# 281474981541259	6.36	7.08
# 281474981541259	7.08	7.32
# 281474981541259	7.32	7.86
# 281474981541259	7.86	9.120000000000001
#
#
# ==================================================
#
# Contents of 281474982590420.txt:
#
# 281474982590420	0.36	0.75
# 281474982590420	0.75	1.08
# 281474982590420	1.08	1.2000000000000002
# 281474982590420	1.2000000000000002	1.4700000000000002
# 281474982590420	1.47	1.68
# 281474982590420	1.6800000000000002	1.9500000000000002
# 281474982590420	1.9500000000000002	2.0700000000000003
# 281474982590420	2.0999999999999996	2.3699999999999997
# 281474982590420	2.37	2.64
# 281474982590420	2.64	2.8200000000000003
# 281474982590420	2.82	3.03
#
#
# ==================================================
#
# Contents of 281474981693204.txt:
#
# 281474981693204	0.75	0.99
# 281474981693204	0.99	1.26
# 281474981693204	1.26	1.4100000000000001
# 281474981693204	1.41	1.68
# 281474981693204	1.71	1.92
# 281474981693204	1.92	2.04
# 281474981693204	2.04	2.37
# 281474981693204	2.4000000000000004	2.7
# 281474981693204	2.73	3.0
# 281474981693204	3.0300000000000002	3.3000000000000003
#
#
# ==================================================
#
# Contents of 281474979746087.txt:
#
# 281474979746087	0.09	0.42000000000000004
#
#
# ==================================================
#
# Contents of 281474979551557.txt:
#
# 281474979551557	0.66	1.1400000000000001
# 281474979551557	1.1400000000000001	1.5
# 281474979551557	1.5	1.62
# 281474979551557	1.62	1.9500000000000002
# 281474979551557	1.9500000000000002	2.1
# 281474979551557	2.0999999999999996	2.4899999999999998
# 281474979551557	2.55	2.6399999999999997
# 281474979551557	2.64	2.7600000000000002
# 281474979551557	2.7600000000000002	3.18
# 281474979551557	3.18	3.3600000000000003
# 281474979551557	3.3600000000000003	3.8100000000000005
#
#
# ==================================================
#
# Contents of 281474980285786.txt:
#
# 281474980285786	1.08	1.59
#
#
# ==================================================
#
# Contents of 281474977490102.txt:
#
# 281474977490102	1.1099999999999999	1.5299999999999998
# 281474977490102	1.53	1.6800000000000002
# 281474977490102	1.6800000000000002	2.04
# 281474977490102	2.04	2.46
# 281474977490102	2.46	2.58
# 281474977490102	2.58	2.94
# 281474977490102	2.94	3.24
# 281474977490102	3.24	3.39
# 281474977490102	3.3899999999999997	3.7199999999999998
# 281474977490102	3.7199999999999998	4.109999999999999
#
#
# ==================================================
#
# Contents of 281474978155610.txt:
#
# 281474978155610	0.42000000000000004	0.81
# 281474978155610	0.81	1.17
# 281474978155610	1.17	1.3199999999999998
# 281474978155610	1.32	1.6800000000000002
# 281474978155610	1.7999999999999998	2.0999999999999996
# 281474978155610	2.0999999999999996	2.3999999999999995
#
#
# ==================================================
#
# Contents of 281474982577899.txt:
#
# 281474982577899	0.39	0.93
# 281474982577899	0.9299999999999999	1.62
# 281474982577899	1.62	2.16
# 281474982577899	2.16	2.7300000000000004
# 281474982577899	2.73	3.06
# 281474982577899	3.06	3.45
# 281474982577899	3.4499999999999997	3.8699999999999997
# 281474982577899	3.9000000000000004	4.23
#
#
# ==================================================
#
# Contents of 281474982586486.txt:
#
# 281474982586486	0.0	0.51
# 281474982586486	0.51	0.87
# 281474982586486	0.8699999999999999	1.23
# 281474982586486	1.23	1.68
# 281474982586486	1.6800000000000002	2.0700000000000003
# 281474982586486	2.07	2.6399999999999997
#
#
# ==================================================
#
# Contents of 281474982647510.txt:
#
# 281474982647510	1.1400000000000001	1.77
# 281474982647510	1.77	2.01
# 281474982647510	2.0100000000000002	2.37
# 281474982647510	2.37	2.7
# 281474982647510	2.7	3.0
# 281474982647510	3.0	3.33
# 281474982647510	3.33	3.5700000000000003
#
#
# ==================================================
#
# Contents of 281474977944491.txt:
#
# 281474977944491	0.18	0.54
# 281474977944491	0.54	0.6900000000000001
# 281474977944491	0.6900000000000001	0.9900000000000001
# 281474977944491	0.99	1.1099999999999999
# 281474977944491	1.1099999999999999	1.44
# 281474977944491	1.44	1.77
# 281474977944491	1.77	2.16
# 281474977944491	2.16	2.52
# 281474977944491	2.52	2.91
# 281474977944491	2.91	3.12
# 281474977944491	3.2700000000000005	3.99
#
#
# ==================================================
#
# Contents of 281474982209265.txt:
#
# 281474982209265	0.0	0.48
# 281474982209265	0.48	0.81
# 281474982209265	0.81	0.93
# 281474982209265	0.9299999999999999	1.1099999999999999
# 281474982209265	1.1099999999999999	1.41
#
#
# ==================================================
#
# Contents of 281474980903278.txt:
#
# 281474980903278	0.66	1.1099999999999999
# 281474980903278	1.1099999999999999	1.77
# 281474980903278	1.83	2.16
# 281474980903278	2.16	2.79
# 281474980903278	2.8499999999999996	3.5699999999999994
# 281474980903278	3.57	4.2
# 281474980903278	4.199999999999999	4.9799999999999995
# 281474980903278	4.9799999999999995	5.64
# 281474980903278	5.7299999999999995	6.119999999999999
# 281474980903278	6.66	7.26
# 281474980903278	7.3500000000000005	7.5600000000000005
# 281474980903278	7.59	8.07
# 281474980903278	8.07	8.49
# 281474980903278	8.49	9.0
#
#
# ==================================================
#
# Contents of 281474982294187.txt:
#
# 281474982294187	0.63	1.44
#
#
# ==================================================
#
# Contents of 281474979565787.txt:
#
# 281474979565787	0.42000000000000004	0.9
# 281474979565787	0.8999999999999999	1.6199999999999999
# 281474979565787	1.71	2.1
# 281474979565787	2.0999999999999996	2.3999999999999995
# 281474979565787	2.4000000000000004	2.8200000000000003
# 281474979565787	2.82	3.0
# 281474979565787	3.0	3.48
# 281474979565787	3.4799999999999995	4.109999999999999
#
#
# ==================================================
#
# Contents of 281474977648654.txt:
#
# 281474977648654	0.6900000000000001	1.5300000000000002
#
#
# ==================================================
#
# Contents of 281474981278880.txt:
#
# 281474981278880	1.59	2.13
# 281474981278880	2.13	2.9699999999999998
# 281474981278880	2.9699999999999998	3.3299999999999996
# 281474981278880	3.3600000000000003	3.7500000000000004
# 281474981278880	3.75	4.11
# 281474981278880	4.11	4.5600000000000005
# 281474981278880	4.5600000000000005	5.130000000000001
# 281474981278880	5.13	5.609999999999999
# 281474981278880	5.61	6.24
# 281474981278880	6.27	6.6
# 281474981278880	6.63	7.2
# 281474981278880	7.199999999999999	7.68
#
#
# ==================================================
#
# Contents of 281474982647496.txt:
#
# 281474982647496	1.29	1.83
# 281474982647496	1.83	2.52
# 281474982647496	2.52	2.91
# 281474982647496	3.0300000000000002	3.5700000000000003
# 281474982647496	3.57	3.9899999999999998
# 281474982647496	3.99	4.470000000000001
#
#
# ==================================================
#
# Contents of 281474982580159.txt:
#
# 281474982580159	0.30000000000000004	0.9600000000000001
# 281474982580159	0.96	1.56
# 281474982580159	1.62	2.0700000000000003
# 281474982580159	2.07	2.6399999999999997
# 281474982580159	2.64	2.91
# 281474982580159	2.9699999999999998	3.36
# 281474982580159	3.3600000000000003	4.140000000000001
# 281474982580159	4.14	4.35
# 281474982580159	4.35	4.859999999999999
# 281474982580159	4.86	5.76
#
#
# ==================================================
#
# Contents of 281474982298411.txt:
#
# 281474982298411	0.63	1.17
#
#
# ==================================================
#
# Contents of 281474982644968.txt:
#
# 281474982644968	0.75	1.1400000000000001
# 281474982644968	1.1400000000000001	1.4400000000000002
# 281474982644968	1.44	1.71
# 281474982644968	1.71	1.83
# 281474982644968	1.83	2.0100000000000002
# 281474982644968	2.0100000000000002	2.2800000000000002
# 281474982644968	2.2800000000000002	2.37
# 281474982644968	2.37	2.67
#
#
# ==================================================
#
# Contents of 281474979554146.txt:
#
# 281474979554146	0.36	0.75
#
#
# ==================================================
#
# Contents of 281474981693235.txt:
#
# 281474981693235	1.29	2.04
# 281474981693235	2.67	3.3899999999999997
# 281474981693235	3.3899999999999997	4.05
# 281474981693235	5.07	5.880000000000001
# 281474981693235	5.88	6.27
# 281474981693235	6.27	6.6899999999999995
# 281474981693235	8.94	9.45
# 281474981693235	9.45	9.78
# 281474981693235	9.84	10.26
# 281474981693235	10.620000000000001	11.370000000000001
# 281474981693235	11.73	12.21
# 281474981693235	12.57	13.950000000000001
# 281474981693235	14.25	14.73
#
#
# ==================================================
#
# Contents of 281474981690648.txt:
#
# 281474981690648	0.33	0.75
# 281474981690648	0.75	0.9
# 281474981690648	0.8999999999999999	1.29
# 281474981690648	1.29	1.83
# 281474981690648	1.98	2.46
# 281474981690648	2.46	2.64
# 281474981690648	2.64	2.97
# 281474981690648	2.9699999999999998	3.3299999999999996
# 281474981690648	3.3600000000000003	3.66
#
#
# ==================================================
#
# Contents of 281474977673370.txt:
#
# 281474977673370	0.99	1.44
# 281474977673370	1.5	2.04
# 281474977673370	2.04	2.07
# 281474977673370	2.07	2.79
# 281474977673370	3.18	3.81
# 281474977673370	3.81	3.99
# 281474977673370	3.99	4.44
# 281474977673370	4.4399999999999995	4.829999999999999
# 281474977673370	4.86	5.37
# 281474977673370	5.37	6.09
# 281474977673370	6.09	6.4799999999999995
# 281474977673370	6.48	6.87
# 281474977673370	6.87	7.140000000000001
# 281474977673370	7.17	7.56
#
#
# ==================================================
#
# Contents of 281474981275143.txt:
#
# 281474981275143	0.39	0.9
#
#
# ==================================================
#
# Contents of 281474982581905.txt:
#
# 281474982581905	0.15000000000000002	0.66
#
#
# ==================================================
#
# Contents of 281474980263350.txt:
#
# 281474980263350	0.9299999999999999	1.35
#
#
# ==================================================
#
# Contents of 281474977520023.txt:
#
# 281474977520023	0.44999999999999996	0.96
# 281474977520023	0.96	1.26
# 281474977520023	1.26	1.62
# 281474977520023	1.62	1.77
# 281474977520023	1.77	2.2800000000000002
# 281474977520023	2.31	2.85
# 281474977520023	2.91	3.1500000000000004
# 281474977520023	3.1500000000000004	3.45
# 281474977520023	3.4499999999999997	3.78
# 281474977520023	3.7800000000000002	4.17
# 281474977520023	4.26	4.38
# 281474977520023	4.4399999999999995	4.739999999999999
# 281474977520023	4.74	5.13
#
#
# ==================================================
#
# Contents of 281474980724207.txt:
#
# 281474980724207	1.7399999999999998	2.1599999999999997
#
#
# ==================================================
#
# Contents of 281474981948002.txt:
#
# 281474981948002	1.32	2.16
# 281474981948002	2.16	2.7
# 281474981948002	3.18	4.0200000000000005
# 281474981948002	4.0200000000000005	4.620000000000001
# 281474981948002	4.68	5.1
# 281474981948002	5.4	6.15
# 281474981948002	6.1499999999999995	6.81
# 281474981948002	6.8100000000000005	7.5600000000000005
# 281474981948002	7.59	8.16
#
#
# ==================================================
#
# Contents of 281474982731488.txt:
#
# 281474982731488	0.99	1.26
# 281474982731488	1.26	1.62
# 281474982731488	1.62	1.77
# 281474982731488	1.7999999999999998	2.2199999999999998
# 281474982731488	2.2199999999999998	2.67
# 281474982731488	2.67	2.9699999999999998
# 281474982731488	2.9699999999999998	3.3
# 281474982731488	3.3000000000000003	3.72
# 281474982731488	3.75	4.17
# 281474982731488	4.199999999999999	4.589999999999999
#
#
# ==================================================
#
# Contents of 281474982734080.txt:
#
# 281474982734080	0.39	0.81
# 281474982734080	0.81	0.9600000000000001
# 281474982734080	0.96	1.26
# 281474982734080	1.26	1.4100000000000001
# 281474982734080	1.41	1.6199999999999999
# 281474982734080	1.62	1.77
# 281474982734080	1.77	2.13
# 281474982734080	2.13	2.34
#
#
# ==================================================
#
# Contents of 281474979755779.txt:
#
# 281474979755779	1.92	2.73
#
#
# ==================================================
#
# Contents of 281474982488517.txt:
#
# 281474982488517	0.30000000000000004	1.11
# 281474982488517	1.1099999999999999	1.2599999999999998
# 281474982488517	1.26	2.01
# 281474982488517	2.0100000000000002	2.5500000000000003
# 281474982488517	2.55	3.33
# 281474982488517	3.33	3.54
# 281474982488517	3.54	4.08
# 281474982488517	4.08	4.44
# 281474982488517	4.4399999999999995	4.8
# 281474982488517	4.800000000000001	5.1000000000000005
#
#
# ==================================================
#
# Contents of 281474978296401.txt:
#
# 281474978296401	0.39	0.9
# 281474978296401	0.9299999999999999	1.26
# 281474978296401	1.26	1.53
# 281474978296401	1.53	2.1
# 281474978296401	2.0999999999999996	2.5199999999999996
# 281474978296401	2.52	2.85
# 281474978296401	2.88	3.33
#
#
# ==================================================
#
# Contents of 281474977748055.txt:
#
# 281474977748055	0.42000000000000004	0.9
# 281474977748055	0.8999999999999999	1.0799999999999998
# 281474977748055	1.08	1.59
# 281474977748055	1.62	2.16
# 281474977748055	2.31	2.8200000000000003
# 281474977748055	2.82	3.21
# 281474977748055	3.24	3.66
# 281474977748055	3.66	4.17
# 281474977748055	4.89	5.16
# 281474977748055	5.16	5.61
#
#
# ==================================================
#
# Contents of 281474982756239.txt:
#
# 281474982756239	1.17	1.83
#
#
# ==================================================
#
# Contents of 281474982593450.txt:
#
# 281474982593450	0.06	0.51
# 281474982593450	0.51	0.99
# 281474982593450	0.99	1.17
# 281474982593450	1.17	1.65
# 281474982593450	1.6500000000000001	1.9500000000000002
# 281474982593450	1.98	2.46
# 281474982593450	2.46	2.73
# 281474982593450	2.73	3.27
#
#
# ==================================================
#
# Contents of 281474982582978.txt:
#
# 281474982582978	0.30000000000000004	0.81
# 281474982582978	0.81	0.99
# 281474982582978	0.99	1.26
# 281474982582978	1.26	1.44
# 281474982582978	1.44	1.77
# 281474982582978	1.77	1.8900000000000001
# 281474982582978	1.8900000000000001	2.34
# 281474982582978	2.34	2.55
# 281474982582978	2.55	2.9099999999999997
# 281474982582978	2.91	3.45
# 281474982582978	3.4499999999999997	3.75
# 281474982582978	3.75	3.87
# 281474982582978	3.87	4.29
#
#
# ==================================================
#
# Contents of 281474978364078.txt:
#
# 281474978364078	0.51	1.11
#
#
# ==================================================
#
# Contents of 281474982580216.txt:
#
# 281474982580216	0.36	0.87
# 281474982580216	0.8699999999999999	1.0799999999999998
# 281474982580216	1.08	1.59
# 281474982580216	1.59	1.9500000000000002
# 281474982580216	2.0100000000000002	2.3400000000000003
# 281474982580216	2.43	2.8200000000000003
# 281474982580216	3.24	3.66
# 281474982580216	3.66	3.99
# 281474982580216	3.99	4.41
# 281474982580216	4.41	4.5600000000000005
# 281474982580216	4.5600000000000005	5.130000000000001
#
#
# ==================================================
#
# Contents of 281474982645694.txt:
#
# 281474982645694	0.06	0.39
# 281474982645694	0.44999999999999996	0.72
# 281474982645694	0.72	1.1099999999999999
# 281474982645694	1.1099999999999999	1.2899999999999998
# 281474982645694	1.29	1.71
# 281474982645694	1.71	2.1
# 281474982645694	2.0999999999999996	2.5199999999999996
# 281474982645694	2.52	2.76
# 281474982645694	2.7600000000000002	3.0600000000000005
#
#
# ==================================================
#
# Contents of 281474982584716.txt:
#
# 281474982584716	0.0	0.36
# 281474982584716	0.42000000000000004	0.75
# 281474982584716	0.75	0.9
# 281474982584716	0.9299999999999999	1.29
# 281474982584716	1.29	1.59
# 281474982584716	1.59	1.9500000000000002
# 281474982584716	1.9500000000000002	2.1900000000000004
# 281474982584716	2.19	2.58
# 281474982584716	2.58	2.8200000000000003
# 281474982584716	2.82	3.1799999999999997
#
#
# ==================================================
#
# Contents of 281474981808810.txt:
#
# 281474981808810	1.92	2.52
# 281474981808810	2.52	3.0
# 281474981808810	3.0	3.45
# 281474981808810	3.4499999999999997	3.9899999999999998
# 281474981808810	3.99	4.53
# 281474981808810	4.59	4.859999999999999
# 281474981808810	4.86	5.16
# 281474981808810	5.16	5.34
# 281474981808810	5.34	5.9399999999999995
#
#
# ==================================================
#
# Contents of 281474978155591.txt:
#
# 281474978155591	0.36	0.87
# 281474978155591	0.8699999999999999	1.02
# 281474978155591	1.02	1.38
# 281474978155591	1.3800000000000001	1.83
# 281474978155591	1.83	2.19
# 281474978155591	2.19	2.49
# 281474978155591	2.8499999999999996	3.42
# 281474978155591	3.42	3.75
# 281474978155591	3.75	4.29
# 281474978155591	4.29	4.59
# 281474978155591	4.59	5.13
# 281474978155591	5.13	5.7
#
#
# ==================================================
#
# Contents of 281474977519672.txt:
#
# 281474977519672	1.0499999999999998	1.44
# 281474977519672	1.44	1.92
# 281474977519672	1.92	2.19
# 281474977519672	2.2199999999999998	2.6399999999999997
# 281474977519672	2.64	2.97
# 281474977519672	2.9699999999999998	3.36
# 281474977519672	3.54	4.02
# 281474977519672	4.0200000000000005	4.590000000000001
# 281474977519672	5.25	5.61
# 281474977519672	5.61	5.94
# 281474977519672	5.97	6.359999999999999
#
#
# ==================================================
#
# Contents of 281474981817360.txt:
#
# 281474981817360	1.02	1.56
# 281474981817360	1.56	1.9500000000000002
# 281474981817360	1.9500000000000002	2.1
# 281474981817360	2.0999999999999996	2.3099999999999996
# 281474981817360	2.31	2.64
# 281474981817360	2.64	3.0
# 281474981817360	3.0	3.27
# 281474981817360	3.2700000000000005	3.5100000000000007
#
#
# ==================================================
#
# Contents of 281474982593807.txt:
#
# 281474982593807	0.44999999999999996	0.8999999999999999
# 281474982593807	0.8999999999999999	0.9299999999999999
# 281474982593807	0.9299999999999999	1.14
# 281474982593807	1.2000000000000002	1.5000000000000002
# 281474982593807	1.5	1.98
# 281474982593807	1.98	2.34
# 281474982593807	2.34	2.76
#
#
# ==================================================
#
# Contents of 281474981691440.txt:
#
# 281474981691440	0.36	0.84
# 281474981691440	0.8400000000000001	0.9600000000000001
# 281474981691440	0.96	1.35
# 281474981691440	1.35	1.86
# 281474981691440	2.0100000000000002	2.46
# 281474981691440	2.4899999999999998	3.15
# 281474981691440	3.4799999999999995	3.8999999999999995
# 281474981691440	3.9000000000000004	4.23
# 281474981691440	4.26	4.5
# 281474981691440	4.5	4.98
#
#
# ==================================================
#
# Contents of 281474982583584.txt:
#
# 281474982583584	0.5700000000000001	0.9600000000000001
# 281474982583584	0.96	1.17
# 281474982583584	1.17	1.56
# 281474982583584	1.62	1.98
# 281474982583584	2.0100000000000002	2.4000000000000004
#
#
# ==================================================
#
# Contents of 281474978176065.txt:
#
# 281474978176065	1.2000000000000002	2.31
#
#
# ==================================================
#
# Contents of 281474982125407.txt:
#
# 281474982125407	0.48	0.9
# 281474982125407	0.8999999999999999	1.1099999999999999
# 281474982125407	1.2000000000000002	1.6500000000000001
# 281474982125407	1.6500000000000001	2.16
# 281474982125407	2.16	2.3400000000000003
# 281474982125407	2.34	2.91
# 281474982125407	2.9699999999999998	3.09
# 281474982125407	3.1500000000000004	3.5700000000000003
# 281474982125407	3.57	3.9299999999999997
# 281474982125407	3.93	4.3500000000000005
#
#
# ==================================================
#
# Contents of 281474981377871.txt:
#
# 281474981377871	0.8400000000000001	1.3800000000000001
# 281474981377871	1.3800000000000001	2.1
# 281474981377871	2.0999999999999996	2.4899999999999998
#
#
# ==================================================
#
# Contents of 281474982580098.txt:
#
# 281474982580098	0.09	0.42000000000000004
# 281474982580098	0.42000000000000004	0.54
# 281474982580098	0.54	0.8400000000000001
# 281474982580098	0.8400000000000001	1.05
# 281474982580098	1.0499999999999998	1.4099999999999997
# 281474982580098	1.41	1.56
# 281474982580098	1.56	1.9500000000000002
#
#
# ==================================================
#
# Contents of 281474979960755.txt:
#
# 281474979960755	0.75	1.38
# 281474979960755	1.3800000000000001	1.62
# 281474979960755	1.62	2.1
# 281474979960755	2.0999999999999996	2.3699999999999997
# 281474979960755	2.43	2.91
# 281474979960755	2.94	3.36
# 281474979960755	3.3600000000000003	3.72
# 281474979960755	3.7199999999999998	4.38
#
#
# ==================================================
#
# Contents of 281474981388708.txt:
#
# 281474981388708	0.81	1.29
#
#
# ==================================================
#
# Contents of 281474982645949.txt:
#
# 281474982645949	0.33	0.9000000000000001
# 281474982645949	0.8999999999999999	1.0499999999999998
# 281474982645949	1.0499999999999998	1.2899999999999998
# 281474982645949	1.83	2.13
# 281474982645949	2.2199999999999998	2.4
# 281474982645949	2.67	3.06
# 281474982645949	3.09	3.42
# 281474982645949	3.42	3.84
#
#
# ==================================================
#
# Contents of 281474982500063.txt:
#
# 281474982500063	0.30000000000000004	0.6900000000000001
# 281474982500063	0.72	0.84
# 281474982500063	0.8699999999999999	1.17
# 281474982500063	1.17	1.23
# 281474982500063	1.23	1.5
# 281474982500063	1.5	1.83
# 281474982500063	1.83	2.19
# 281474982500063	2.2199999999999998	2.34
# 281474982500063	2.34	2.67
# 281474982500063	2.67	3.06
# 281474982500063	3.06	3.3
# 281474982500063	3.3000000000000003	3.4200000000000004
# 281474982500063	3.42	3.75
#
#
# ==================================================
#
# Contents of 281474980270830.txt:
#
# 281474980270830	1.26	1.62
#
#
# ==================================================
#
# Contents of 281474978272723.txt:
#
# 281474978272723	0.6900000000000001	1.11
#
#
# ==================================================
#
# Contents of 281474978326366.txt:
#
# 281474978326366	0.5700000000000001	0.7200000000000001
# 281474978326366	0.72	1.2
# 281474978326366	1.2000000000000002	1.8900000000000001
# 281474978326366	1.8900000000000001	2.2800000000000002
# 281474978326366	2.2800000000000002	2.43
# 281474978326366	2.43	2.7600000000000002
#
#
# ==================================================
#
# Contents of 281474982645381.txt:
#
# 281474982645381	0.44999999999999996	0.9299999999999999
#
#
# ==================================================
#
# Contents of 281474982645154.txt:
#
# 281474982645154	1.44	1.95
#
#
# ==================================================
#
# Contents of 281474978096178.txt:
#
# 281474978096178	0.78	1.32
# 281474978096178	1.32	1.5
# 281474978096178	1.5	1.8900000000000001
# 281474978096178	1.8900000000000001	2.1900000000000004
# 281474978096178	2.19	2.49
#
#
# ==================================================
#
# Contents of 281474979153327.txt:
#
# 281474979153327	0.99	1.5
# 281474979153327	1.5	1.71
# 281474979153327	1.71	2.1
# 281474979153327	2.0999999999999996	2.4599999999999995
# 281474979153327	2.46	2.79
# 281474979153327	2.79	3.06
# 281474979153327	3.06	3.33
# 281474979153327	3.33	3.69
# 281474979153327	3.69	4.11
# 281474979153327	4.11	4.44
# 281474979153327	4.4399999999999995	4.619999999999999
# 281474979153327	4.62	5.01
# 281474979153327	5.01	5.37
# 281474979153327	5.37	5.5200000000000005
# 281474979153327	5.5200000000000005	5.91
# 281474979153327	5.9399999999999995	6.239999999999999
#
#
# ==================================================
#
# Contents of 281474979567249.txt:
#
# 281474979567249	1.35	1.8900000000000001
# 281474979567249	1.8900000000000001	2.49
# 281474979567249	2.61	2.76
# 281474979567249	2.7600000000000002	3.33
# 281474979567249	3.33	3.93
# 281474979567249	3.93	4.23
# 281474979567249	4.2299999999999995	4.619999999999999
# 281474979567249	4.62	4.7700000000000005
# 281474979567249	4.7700000000000005	5.19
# 281474979567249	5.1899999999999995	5.34
# 281474979567249	5.34	5.55
# 281474979567249	5.58	5.94
#
#
# ==================================================
#
# Contents of 281474982752987.txt:
#
# 281474982752987	0.54	0.8700000000000001
# 281474982752987	0.8699999999999999	0.9599999999999999
# 281474982752987	0.96	1.2
# 281474982752987	1.2000000000000002	1.4700000000000002
# 281474982752987	1.47	1.8900000000000001
#
#
# ==================================================
#
# Contents of 281474979391394.txt:
#
# 281474979391394	0.44999999999999996	0.78
#
#
# ==================================================
#
# Contents of 281474978489324.txt:
#
# 281474978489324	0.8400000000000001	1.1400000000000001
# 281474978489324	1.1400000000000001	1.5
# 281474978489324	1.5	1.98
# 281474978489324	2.0100000000000002	2.5500000000000003
# 281474978489324	2.55	2.9699999999999998
# 281474978489324	2.9699999999999998	3.2699999999999996
# 281474978489324	3.3600000000000003	3.8100000000000005
# 281474978489324	3.81	4.29
# 281474978489324	4.29	4.86
# 281474978489324	4.86	5.5200000000000005
# 281474978489324	5.61	5.8500000000000005
# 281474978489324	5.88	6.33
# 281474978489324	6.36	6.69
#
#
# ==================================================
#
# Contents of 281474981696077.txt:
#
# 281474981696077	0.9299999999999999	1.44
# 281474981696077	1.53	2.01
# 281474981696077	2.0100000000000002	2.4000000000000004
# 281474981696077	2.4000000000000004	2.6400000000000006
# 281474981696077	2.64	3.12
# 281474981696077	3.12	3.6
# 281474981696077	3.63	3.84
# 281474981696077	3.84	4.5
#
#
# ==================================================
#
# Contents of 281474982134493.txt:
#
# 281474982134493	0.42000000000000004	0.78
# 281474982134493	0.78	1.1400000000000001
# 281474982134493	1.1400000000000001	1.56
# 281474982134493	1.59	1.7400000000000002
# 281474982134493	1.7399999999999998	2.0999999999999996
# 281474982134493	2.0999999999999996	2.2499999999999996
# 281474982134493	2.25	2.67
# 281474982134493	2.67	2.82
# 281474982134493	2.82	3.1799999999999997
# 281474982134493	3.21	3.63
# 281474982134493	3.63	4.14
#
#
# ==================================================
#
# Contents of 281474981947948.txt:
#
# 281474981947948	0.8999999999999999	1.5299999999999998
# 281474981947948	1.53	2.22
# 281474981947948	2.2199999999999998	2.9099999999999997
# 281474981947948	2.91	3.4800000000000004
# 281474981947948	3.4799999999999995	3.9599999999999995
# 281474981947948	3.96	4.47
# 281474981947948	4.5	5.04
#
#
# ==================================================
#
# Contents of 281474977585189.txt:
#
# 281474977585189	1.35	1.77
#
#
# ==================================================
#
# Contents of 281474979960752.txt:
#
# 281474979960752	1.08	1.5
#
#
# ==================================================
#
# Contents of 281474982327127.txt:
#
# 281474982327127	0.21000000000000002	0.78
# 281474982327127	0.78	1.62
# 281474982327127	1.71	2.19
# 281474982327127	2.19	2.37
# 281474982327127	2.37	2.73
# 281474982327127	2.73	3.21
# 281474982327127	3.21	3.27
# 281474982327127	3.33	3.63
# 281474982327127	3.63	4.02
# 281474982327127	4.050000000000001	4.32
#
#
# ==================================================
#
# Contents of 281474982399150.txt:
#
# 281474982399150	0.6900000000000001	0.9600000000000001
#
#
# ==================================================
#
# Contents of 281474982580128.txt:
#
# 281474982580128	0.39	0.93
# 281474982580128	0.9299999999999999	1.08
# 281474982580128	1.08	1.4100000000000001
# 281474982580128	1.41	1.83
# 281474982580128	1.83	2.0100000000000002
# 281474982580128	2.0100000000000002	2.3100000000000005
# 281474982580128	2.31	2.76
#
#
# ==================================================
#
# Contents of 281474977511688.txt:
#
# 281474977511688	0.8999999999999999	1.44
# 281474977511688	1.44	1.68
# 281474977511688	1.6800000000000002	2.3400000000000003
# 281474977511688	2.34	2.76
# 281474977511688	2.79	3.18
# 281474977511688	3.18	3.6
# 281474977511688	3.5999999999999996	3.8699999999999997
# 281474977511688	3.9000000000000004	4.2
# 281474977511688	4.199999999999999	4.56
# 281474977511688	4.5600000000000005	4.98
#
#
# ==================================================
#
# Contents of 281474981275456.txt:
#
# 281474981275456	0.63	1.8599999999999999
# 281474981275456	1.8599999999999999	2.46
# 281474981275456	3.21	3.57
# 281474981275456	3.57	4.38
# 281474981275456	4.38	4.98
# 281474981275456	4.9799999999999995	5.819999999999999
# 281474981275456	5.85	6.33
# 281474981275456	6.33	7.05
# 281474981275456	7.050000000000001	7.470000000000001
#
#
# ==================================================
#
# Contents of 281474982135001.txt:
#
# 281474982135001	0.51	0.93
# 281474982135001	0.96	1.08
# 281474982135001	1.08	1.4700000000000002
# 281474982135001	1.47	1.74
# 281474982135001	1.92	2.28
# 281474982135001	2.2800000000000002	2.5200000000000005
# 281474982135001	2.52	2.64
# 281474982135001	2.64	2.97
# 281474982135001	2.9699999999999998	3.1799999999999997
# 281474982135001	3.18	3.54
# 281474982135001	3.54	3.75
# 281474982135001	3.75	3.84
# 281474982135001	3.84	4.17
#
#
# ==================================================
#
# Contents of 281474978391051.txt:
#
# 281474978391051	0.39	1.02
# 281474978391051	1.02	1.38
# 281474978391051	1.3800000000000001	1.7400000000000002
# 281474978391051	1.7399999999999998	2.0999999999999996
# 281474978391051	2.0999999999999996	2.3699999999999997
# 281474978391051	2.37	2.67
# 281474978391051	2.67	3.0
#
#
# ==================================================
#
# Contents of 281474981177984.txt:
#
# 281474981177984	0.78	1.3800000000000001
#
#
# ==================================================
#
# Contents of 281474983045183.txt:
#
# 281474983045183	0.27	1.02
# 281474983045183	1.23	1.47
# 281474983045183	1.47	2.16
# 281474983045183	2.16	2.5500000000000003
# 281474983045183	2.55	2.8499999999999996
# 281474983045183	2.8499999999999996	3.1199999999999997
#
#
# ==================================================
#
# Contents of 281474977682649.txt:
#
# 281474977682649	1.92	2.37
#
#
# ==================================================
#
# Contents of 281474982052265.txt:
#
# 281474982052265	0.27	0.72
# 281474982052265	0.72	1.17
# 281474982052265	1.17	1.41
# 281474982052265	1.41	1.74
# 281474982052265	1.7399999999999998	1.8899999999999997
# 281474982052265	1.92	2.31
# 281474982052265	2.31	2.6100000000000003
# 281474982052265	2.61	2.91
# 281474982052265	2.91	3.27
# 281474982052265	3.2700000000000005	3.4500000000000006
# 281474982052265	3.4499999999999997	3.6599999999999997
# 281474982052265	3.66	4.05
# 281474982052265	4.050000000000001	4.200000000000001
# 281474982052265	4.199999999999999	4.589999999999999
# 281474982052265	4.59	4.74
# 281474982052265	4.74	5.04
# 281474982052265	5.04	5.22
# 281474982052265	5.22	5.55
# 281474982052265	5.550000000000001	5.760000000000001
#
#
# ==================================================
#
# Contents of 281474978597492.txt:
#
# 281474978597492	0.8999999999999999	1.56
#
#
# ==================================================
#
# Contents of 281474982052305.txt:
#
# 281474982052305	0.39	0.75
# 281474982052305	0.75	0.9299999999999999
# 281474982052305	0.9299999999999999	1.38
# 281474982052305	1.3800000000000001	1.83
# 281474982052305	1.83	2.25
# 281474982052305	2.31	2.67
# 281474982052305	2.67	3.1799999999999997
# 281474982052305	3.18	3.6900000000000004
# 281474982052305	3.69	3.99
#
#
# ==================================================
#
# Contents of 281474981960714.txt:
#
# 281474981960714	0.6000000000000001	1.47
# 281474981960714	1.56	2.16
# 281474981960714	2.46	2.76
# 281474981960714	2.7600000000000002	3.2700000000000005
# 281474981960714	3.33	4.05
# 281474981960714	4.050000000000001	4.680000000000001
# 281474981960714	4.86	5.460000000000001
# 281474981960714	5.97	6.6899999999999995
# 281474981960714	7.17	7.56
# 281474981960714	7.5600000000000005	8.31
# 281474981960714	9.69	10.379999999999999
# 281474981960714	10.5	10.89
# 281474981960714	10.92	11.55
# 281474981960714	12.39	13.32
#
#
# ==================================================
#
# Contents of 281474982497279.txt:
#
# 281474982497279	0.15000000000000002	0.6
# 281474982497279	0.6000000000000001	0.7500000000000001
# 281474982497279	0.75	1.05
# 281474982497279	1.0499999999999998	1.2899999999999998
# 281474982497279	1.29	1.59
# 281474982497279	1.59	1.8900000000000001
# 281474982497279	1.8900000000000001	2.2800000000000002
# 281474982497279	2.2800000000000002	2.43
# 281474982497279	2.43	3.0300000000000002
#
#
# ==================================================
#
# Contents of 281474982745387.txt:
#
# 281474982745387	0.8999999999999999	1.71
#
#
# ==================================================
#
# Contents of 281474981819770.txt:
#
# 281474981819770	1.59	2.13
# 281474981819770	2.13	2.4
# 281474981819770	2.4000000000000004	2.8800000000000003
# 281474981819770	2.9699999999999998	3.54
# 281474981819770	3.54	4.140000000000001
# 281474981819770	4.14	4.59
# 281474981819770	4.59	5.07
# 281474981819770	5.07	5.3100000000000005
# 281474981819770	5.3100000000000005	6.090000000000001
#
#
# ==================================================
#
# Contents of 281474981370673.txt:
#
# 281474981370673	1.1400000000000001	1.59
# 281474981370673	1.59	1.83
# 281474981370673	1.83	2.04
# 281474981370673	2.04	2.46
#
#
# ==================================================
#
# Contents of 281474977862560.txt:
#
# 281474977862560	2.58	3.09
# 281474977862560	3.09	3.63
# 281474977862560	3.63	4.14
# 281474977862560	4.14	4.71
# 281474977862560	4.74	5.01
# 281474977862560	5.01	5.3999999999999995
# 281474977862560	5.4	5.91
# 281474977862560	5.91	6.24
# 281474977862560	6.24	6.63
# 281474977862560	6.63	7.29
#
#
# ==================================================
#
# Contents of 281474982210158.txt:
#
# 281474982210158	1.29	1.71
# 281474982210158	1.71	2.25
# 281474982210158	2.2800000000000002	2.49
# 281474982210158	2.4899999999999998	2.9399999999999995
# 281474982210158	3.51	3.78
# 281474982210158	4.2299999999999995	4.709999999999999
# 281474982210158	4.71	5.1
# 281474982210158	5.43	5.97
# 281474982210158	6.51	6.93
# 281474982210158	6.99	7.32
# 281474982210158	7.3500000000000005	7.500000000000001
# 281474982210158	7.5600000000000005	8.190000000000001
# 281474982210158	8.19	8.61
# 281474982210158	8.61	9.389999999999999
# 281474982210158	9.45	9.75
# 281474982210158	9.78	10.17
#
#
# ==================================================
#
# Contents of 281474977678109.txt:
#
# 281474977678109	0.6900000000000001	1.3800000000000001
# 281474977678109	1.3800000000000001	1.56
# 281474977678109	1.56	1.92
# 281474977678109	1.92	2.34
# 281474977678109	2.34	2.73
#
#
# ==================================================
#
# Contents of 281474982292832.txt:
#
# 281474982292832	0.48	1.1099999999999999
# 281474982292832	1.1099999999999999	1.44
# 281474982292832	1.47	1.95
# 281474982292832	1.9500000000000002	2.1900000000000004
# 281474982292832	2.19	2.61
# 281474982292832	2.61	3.0
# 281474982292832	3.0	3.42
# 281474982292832	3.57	4.29
# 281474982292832	4.59	4.8
# 281474982292832	4.800000000000001	5.370000000000001
# 281474982292832	5.37	5.55
# 281474982292832	5.550000000000001	5.82
# 281474982292832	5.82	6.12
#
#
# ==================================================
#
# Contents of 281474977594045.txt:
#
# 281474977594045	1.59	2.25
#
#
# ==================================================
#
# Contents of 281474982852368.txt:
#
# 281474982852368	5.1	5.609999999999999
# 281474982852368	5.61	6.2700000000000005
# 281474982852368	6.27	6.449999999999999
# 281474982852368	6.449999999999999	6.869999999999999
# 281474982852368	6.93	7.109999999999999
# 281474982852368	7.11	7.44
# 281474982852368	7.5	8.1
# 281474982852368	8.100000000000001	8.340000000000002
# 281474982852368	8.34	8.79
# 281474982852368	8.82	9.15
#
#
# ==================================================
#
# Contents of 281474980060646.txt:
#
# 281474980060646	1.0499999999999998	1.44
#
#
# ==================================================
